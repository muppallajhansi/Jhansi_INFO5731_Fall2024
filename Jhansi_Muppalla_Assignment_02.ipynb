# %% [markdown]
# <a href="https://colab.research.google.com/github/muppallajhansi/Jhansi_INFO5731_Fall2024/blob/main/Jhansi_Muppalla_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Tuesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**
#
# **Please check that the link you submitted can be opened and points to the correct assignment.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
import requests
from bs4 import BeautifulSoup
import csv
import time

# Extracted and assigned the url of the imdb movie reviews page to the variable URL U
url = 'https://www.imdb.com/title/tt9362722/reviews/_ajax?ref_=undefined&paginationKey='

# Headers to mimic a real browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Initialized the  variables for the purpose of pagination and reviews
reviews = []
pagination_key = ''
total_reviews_needed = 1000  # top 1000 reviews

# Opened the  CSV file for the purpose of writing
with open('imdb_reviews.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Write header row

    # Loop to go through all the pages until we have enough(1000) reviews
    while len(reviews) < total_reviews_needed:
        # Construct the full URL with the pagination key
        full_url = url + pagination_key

        # Sending a GET request to  URL
        response = requests.get(full_url, headers=headers)

        # Parsing the page content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Finding all the review-containers
        new_reviews = soup.find_all('div', class_='text show-more__control')

        # If no new reviews are being found, break the loop which is (end of pages)
        if not new_reviews:
            print("No more reviews found.")
            break

        # Adding  the new reviews to the final or the total list
        for review in new_reviews:
            review_text = review.get_text().strip()
            if len(reviews) < total_reviews_needed:
                reviews.append(review_text)
                writer.writerow([review_text])
            else:
                break  # Break if we already have the 1000 reviews

        # Update the pagination key for the next page
        load_more_data = soup.find('div', {'class': 'load-more-data'})
        if load_more_data and load_more_data.has_attr('data-key'):
            pagination_key = load_more_data['data-key']
        else:
            break  # Break here, if no pagination key is being found

        # Pausing between requests to avoid being blocked
        time.sleep(1)

# Printing the number of reviews scraped
print(f'Scraped {len(reviews)} reviews successfully!')
# Out:
# Scraped 1000 reviews successfully!

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Downloading the NLTK resources
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import pandas as pd

# Example of reading a CSV file from a URL
url = "/content/imdb_reviews.csv"
df = pd.read_csv(url)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                                               Review
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...

# %% [markdown]
# # (1) Remove noise, such as special characters and punctuations.

# %%
import re
def remove_noise(text):
    return re.sub(r'[^A-Za-z\s]', '', text)  # Keep only letters and whitespace

# Applying the function to remove noise
df['Noisy Removed'] = df['Review'].apply(remove_noise)

# Display the updated DataFrame with original and cleaned reviews
print(df[['Review', 'Noisy Removed']].head())
# Out:
#                                               Review  \
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...
#
#                                        Noisy Removed
# 0  Its honestly absurd how good the SpiderVerse m...
# 1  If it wasnt already obvious in the first film ...
# 2  First off you should know that this is the fir...
# 3  This film is a visual concert The animation an...
# 4  The animation flow of everything genius charac...

# %% [markdown]
# # (2) Remove numbers.

# %%
# Function to remove numbers
def remove_numbers(text):
    return re.sub(r'\d+', '', text)  # Remove all digits

# Apply the function to remove numbers from the 'Noisy Removed' column
df['Numbers Removed'] = df['Noisy Removed'].apply(remove_numbers)

# Display the updated DataFrame with original, cleaned, and number-removed reviews
print(df[['Review', 'Noisy Removed', 'Numbers Removed']].head())
# Out:
#                                               Review  \
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...
#
#                                        Noisy Removed  \
# 0  Its honestly absurd how good the SpiderVerse m...
# 1  If it wasnt already obvious in the first film ...
# 2  First off you should know that this is the fir...
# 3  This film is a visual concert The animation an...
# 4  The animation flow of everything genius charac...
#
#                                      Numbers Removed
# 0  Its honestly absurd how good the SpiderVerse m...
# 1  If it wasnt already obvious in the first film ...
# 2  First off you should know that this is the fir...
# 3  This film is a visual concert The animation an...
# 4  The animation flow of everything genius charac...

# %% [markdown]
# # (3) Remove stopwords by using the stopwords list.

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords

# Downloading the NLTK resources if not already available
nltk.download('stopwords')

# Initializing the stopwords
stop_words = set(stopwords.words('english'))

# Function for removing the stopwords
def remove_stopwords(text):
    text_tokens = text.split()  # Split the text into tokens (words)
    return ' '.join([word for word in text_tokens if word.lower() not in stop_words])  # Remove stopwords and join back to string

# Applying the function to remove stopwords from the 'Numbers Removed' column
df['Stopwords Removed'] = df['Numbers Removed'].apply(remove_stopwords)

# Displaying the updated DataFrame with original review and stopwords removed
print(df[['Review', 'Stopwords Removed']].head())
# Out:
#                                               Review  \
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...
#
#                                    Stopwords Removed
# 0  honestly absurd good SpiderVerse movies Across...
# 1  wasnt already obvious first film officially cl...
# 2  First know first part one big movie split two ...
# 3  film visual concert animation character design...
# 4  animation flow everything genius character dev...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # (4) Lowercase all texts

# %%
# Function for lowercasing all texts
def lowercase_text(text):
    return text.lower()  # Convert text to lowercase

# Applying the function to the 'Stopwords Removed' column
df['Lowercased'] = df['Stopwords Removed'].apply(lowercase_text)

# Displaying the updated DataFrame with the original review and lowercased text
print(df[['Review', 'Lowercased']].head())
# Out:
#                                               Review  \
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...
#
#                                           Lowercased
# 0  honestly absurd good spiderverse movies across...
# 1  wasnt already obvious first film officially cl...
# 2  first know first part one big movie split two ...
# 3  film visual concert animation character design...
# 4  animation flow everything genius character dev...

# %% [markdown]
# # (5) Stemming.

# %%
from nltk.stem import PorterStemmer

# Initializing the stemmer
stemmer = PorterStemmer()

# Function for the purpose of stemming
def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])  # Apply stemming to each word

# Applying the function to the 'Lowercased' column
df['Stemmed'] = df['Lowercased'].apply(stem_text)

# Displaying the updated DataFrame with the original review and stemmed text
print(df[['Review', 'Stemmed']].head())
# Out:
#                                               Review  \
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...
#
#                                              Stemmed
# 0  honestli absurd good spidervers movi across sp...
# 1  wasnt alreadi obviou first film offici clear d...
# 2  first know first part one big movi split two h...
# 3  film visual concert anim charact design neatli...
# 4  anim flow everyth geniu charact develop action...

# %% [markdown]
# # (6) Lemmatization.

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (13 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 5.1 MB/s eta 0:00:00
# Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.1.0 textsearch-0.0.24

# %%
import pandas as pd
import spacy
import contractions

# Load the English NLP model
nlp = spacy.load('en_core_web_sm')

# Assuming you already have your DataFrame named df
# df = pd.read_csv('your_file.csv')

# Function to expand contractions
def expand_contractions(text):
    return contractions.fix(text)  # Expanding contractions

# Function for lemmatization using spaCy
def lemmatize_text(text):
    doc = nlp(text)  # Process the text with spaCy
    return ' '.join([token.lemma_ for token in doc])  # Join lemmas into a string

# Applying the function to expand contractions and then lemmatize
df['Lemmatized'] = df['Stemmed'].apply(expand_contractions).apply(lemmatize_text)

# Displaying the updated DataFrame with original review and lemmatized text
print(df[['Review', 'Lemmatized']].head())
# Out:
#                                               Review  \
# 0  It's honestly absurd how good the "Spider-Vers...
# 1  If it wasn't already obvious in the first film...
# 2  First off, you should know that this is the fi...
# 3  This film is a visual concert. The animation a...
# 4  The animation, flow of everything, genius char...
#
#                                           Lemmatized
# 0  honestli absurd good spiderver movi across spi...
# 1  be not alreadi obviou first film offici clear ...
# 2  first know first part one big movi split two h...
# 3  film visual concert anim charact design neatli...
# 4  anim flow everyth geniu charact develop action...

# %%
# Saving the cleaned data to a new CSV file called 'imdb_reviews_cleaned.csv'
df.to_csv('imdb_reviews_cleaned.csv', index=False)  # Use the variable name for your DataFrame

# Print a confirmation message
print("Cleaned data saved to 'imdb_reviews_cleaned.csv'")
# Out:
# Cleaned data saved to 'imdb_reviews_cleaned.csv'

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %% [markdown]
# # (1) Parts of Speech (POS) Tagging

# %%
import nltk
import pandas as pd
from collections import Counter

# Downloading all necessary NLTK data
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Function for POS tagging
def pos_tagging(text):
    words = nltk.word_tokenize(text)  # Tokenize the text
    pos_tags = nltk.pos_tag(words)     # Get POS tags
    return pos_tags

# Function to count POS tags
def count_pos(pos_tags):
    pos_counts = Counter(tag for word, tag in pos_tags)  # Count POS tags
    return {
        'Nouns': sum(pos_counts[tag] for tag in ['NN', 'NNS', 'NNP', 'NNPS']),
        'Verbs': sum(pos_counts[tag] for tag in ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']),
        'Adjectives': sum(pos_counts[tag] for tag in ['JJ', 'JJR', 'JJS']),
        'Adverbs': sum(pos_counts[tag] for tag in ['RB', 'RBR', 'RBS'])
    }

# Loading the cleaned data
dataFrame = pd.read_csv('imdb_reviews_cleaned.csv')

# Performing POS tagging on cleaned text
dataFrame['POS_tags'] = dataFrame['Lemmatized'].apply(pos_tagging)

# Counting the POS for each review
dataFrame['POS_counts'] = dataFrame['POS_tags'].apply(count_pos)

# Calculating the total POS counts
total_pos_counts = dataFrame['POS_counts'].apply(pd.Series).sum()

# Display total POS counts
print("Total POS counts:")
print(total_pos_counts)

# Saving all results to a CSV file
dataFrame.to_csv('imdb_reviews_pos_tagged.csv', index=False)
print("POS tagging results saved to 'imdb_reviews_pos_tagged.csv'")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Total POS counts:
# Nouns         57117
# Verbs         16042
# Adjectives    22432
# Adverbs        7637
# dtype: int64
# POS tagging results saved to 'imdb_reviews_pos_tagged.csv'

# %% [markdown]
# # (2) Constituency Parsing and Dependency Parsing

# %%
import nltk
import spacy
from nltk import Tree
import pandas as pd

# Downloading all the necessary NLTK data quietly
nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('maxent_ne_chunker', quiet=True)
nltk.download('words', quiet=True)

# Loading the spaCy model
nlp = spacy.load("en_core_web_sm")

# Function for constituency parsing
def constituency_parse(sentence):
    words = nltk.word_tokenize(sentence)  # Tokenize the sentence
    pos_tags = nltk.pos_tag(words)        # Get POS tags
    tree = nltk.ne_chunk(pos_tags)        # Create the parse tree
    return tree

# Function for dependency parsing
def dependency_parse(sentence):
    doc = nlp(sentence)                    # Process the sentence with spaCy
    return [(token.text, token.dep_, token.head.text) for token in doc]

# Loading the cleaned data from CSV file
dataFrame = pd.read_csv('imdb_reviews_cleaned.csv')

# Processing all the sentences
for index, row in dataFrame.iterrows():
    sentence = row['Lemmatized']  # Access the lemmatized sentence
    print(f"\n\nSentence {index + 1}:")
    print(sentence)

    # Constituency parsing
    try:
        print("\nConstituency Parse Tree:")
        constituency_tree = constituency_parse(sentence)
        print(constituency_tree)
    except LookupError as e:
        print(f"Error in constituency parsing: {e}")

    # Dependency parsing
    print("\nDependency Parse:")
    dependency_relations = dependency_parse(sentence)
    for word, dep, head in dependency_relations:
        print(f"{word} --{dep}--> {head}")

print("\nParsing completed for all sentences.")
# Out:
# Streaming output truncated to the last 5000 lines.
#   wisecrack/NN
#   peter/NN
#   b/NN
#   parker/NN
#   enigmat/NN
#   miguel/NN
#   ohara/NN
#   team/NN
#   spiderpeopl/NN
#   form/NN
#   bond/NN
#   endear/JJ
#   empow/NN
#   chemistri/NN
#   growth/NN
#   throughout/IN
#   film/NN
#   keep/VB
#   hook/NN
#   start/VB
#   finishat/WP
#   core/NN
#   film/NN
#   delv/NN
#   profound/NN
#   theme/NN
#   famili/NN
#   friendship/NN
#   selfdiscoveri/JJ
#   explor/NN
#   complex/JJ
#   ident/NN
#   univer/NN
#   desir/NN
#   belong/JJ
#   script/NN
#   master/NN
#   weav/NN
#   theme/NN
#   narr/NN
#   leav/NN
#   last/JJ
#   impact/NN
#   reson/VBD
#   audienc/RB
#   long/JJ
#   credit/NN
#   rollspiderman/NN
#   across/IN
#   spiderver/NN
#   sequel/NN
#   testament/NN
#   power/NN
#   anim/IN
#   art/JJ
#   form/NN
#   transcend/NN
#   boundari/NN
#   genr/NN
#   age/NN
#   appeal/NN
#   young/JJ
#   adult/NN
#   audienc/JJ
#   cinemat/NN
#   achiev/NN
#   rememb/NN
#   landmark/NN
#   anim/NN
#   storytellingin/NN
#   hand/NN
#   visionari/NN
#   filmmak/NN
#   film/NN
#   take/VB
#   bold/JJ
#   risk/NN
#   redefin/NN
#   anim/IN
#   movi/JJ
#   stand/VBP
#   testament/JJ
#   limitless/NN
#   potenti/JJ
#   storytel/NN
#   abil/NN
#   anim/NN
#   transport/VB
#   us/PRP
#   world/NN
#   beyond/IN
#   imaginationin/JJ
#   conclus/JJ
#   spiderman/NN
#   across/IN
#   spiderver/NN
#   extraordinari/NN
#   cinemat/NN
#   experi/JJ
#   demand/NN
#   see/VBP
#   big/JJ
#   screen/NN
#   possibl/NN
#   triumph/NN
#   anim/JJ
#   storytel/NN
#   emot/NN
#   reson/NN
#   solidifi/JJ
#   place/NN
#   pantheon/NN
#   great/JJ
#   film/NN
#   stun/VBD
#   visual/JJ
#   captiv/NN
#   charact/NN
#   profound/JJ
#   theme/NN
#   film/NN
#   testament/JJ
#   power/NN
#   cinema/NN
#   shine/NN
#   exampl/NN
#   magic/JJ
#   achiev/NN
#   visionari/NN
#   mind/NN
#   push/NN
#   boundari/NN
#   storytel/NN
#   simpli/NN
#   put/VBD
#   cinemat/JJ
#   masterpiec/NN
#   age/NN)
#
# Dependency Parse:
# spiderman --nsubj--> place
# across --prep--> spiderman
# spiderver --prep--> spiderman
# absolut --compound--> solidifi
# triumph --compound--> solidifi
# world --compound--> solidifi
# anim --compound--> cinema
# cinema --compound--> solidifi
# solidifi --compound--> place
# place --nsubj--> hold
# modern --amod--> film
# masterpiec --compound--> film
# visuallyarr --compound--> film
# film --dobj--> place
# take --appos--> place
# multiver --appos--> place
# concept --compound--> weav
# weav --nsubj--> breathtak
# breathtak --relcl--> place
# tapestri --compound--> innov
# stun --compound--> anim
# anim --compound--> innov
# innov --dobj--> breathtak
# storytellingfrom --nmod--> spiderman
# first --amod--> spiderman
# frame --compound--> spiderman
# anim --compound--> spiderman
# spiderman --dobj--> place
# across --prep--> spiderman
# spiderver --compound--> grab
# grab --pobj--> across
# hold --ccomp--> see
# sen --compound--> refu
# refu --nsubj--> let
# let --ccomp--> hold
# go --nsubj--> seamlessli
# boldli --compound--> style
# combin --compound--> style
# variou --compound--> style
# style --nsubj--> seamlessli
# seamlessli --compound--> anim
# transit --compound--> anim
# tradit --compound--> anim
# anim --nsubj--> mindbend
# mindbend --ccomp--> let
# spectacl --nsubj--> differ
# differ --ccomp--> mindbend
# univer --advmod--> differ
# result --nsubj--> push
# visual --amod--> feast
# feast --nsubj--> push
# push --nsubj--> candi
# boundari --amod--> anim
# anim --compound--> eye
# achiev --compound--> frame
# everi --compound--> frame
# frame --compound--> meticul
# meticul --compound--> craft
# craft --compound--> eye
# attent --compound--> detail
# detail --compound--> eye
# simpli --compound--> aweinspiringbut
# aweinspiringbut --compound--> eye
# film --compound--> eye
# eye --dobj--> push
# candi --nsubj--> stori
# stori --ccomp--> hold
# heartfelt --advmod--> stori
# exhilar --amod--> continu
# continu --compound--> mile
# mile --dobj--> stori
# moral --amod--> spiderman
# journey --compound--> spiderman
# spiderman --compound--> strike
# screenplay --compound--> strike
# strike --nmod--> moment
# perfect --amod--> blend
# balanc --compound--> blend
# blend --compound--> moment
# moment --compound--> humor
# laughoutloud --compound--> humor
# humor --nsubj--> heartpound
# heartpound --ccomp--> hold
# action --compound--> poignant
# poignant --compound--> emot
# emot --compound--> beat
# beat --nsubj--> take
# take --ccomp--> heartpound
# audienc --amod--> emot
# rollercoast --compound--> emot
# ride --compound--> emot
# emot --compound--> spiderman
# leav --npadvmod--> invest
# invest --amod--> spiderman
# charact --nmod--> spiderman
# fate --compound--> cheer
# cheer --compound--> triumphsspeak
# triumphsspeak --amod--> spiderman
# charact --amod--> spiderman
# spiderman --dobj--> take
# across --prep--> take
# spidervers --compound--> ensembl
# introduc --compound--> ensembl
# captiv --compound--> ensembl
# ensembl --compound--> shine
# shine --nmod--> mile
# respect --compound--> role
# role --compound--> mile
# mile --pobj--> across
# moral --amod--> continu
# flawlessli --amod--> continu
# voic --amod--> continu
# shameik --compound--> moor
# moor --compound--> continu
# continu --compound--> hero
# relat --compound--> hero
# inspir --compound--> hero
# hero --compound--> spirit
# join --compound--> spirit
# spirit --compound--> staci
# gwen --compound--> staci
# staci --appos--> mile
# wisecrack --compound--> b
# peter --compound--> b
# b --compound--> enigmat
# parker --compound--> enigmat
# enigmat --compound--> endear
# miguel --compound--> ohara
# ohara --compound--> team
# team --compound--> endear
# spiderpeopl --compound--> form
# form --compound--> bond
# bond --compound--> endear
# endear --nsubj--> empow
# empow --conj--> hold
# chemistri --amod--> growth
# growth --dobj--> empow
# throughout --prep--> empow
# film --pobj--> throughout
# keep --advcl--> empow
# hook --nsubj--> start
# start --ccomp--> keep
# finishat --det--> ident
# core --compound--> film
# film --nmod--> ident
# delv --nmod--> ident
# profound --nmod--> ident
# theme --compound--> famili
# famili --compound--> friendship
# friendship --compound--> complex
# selfdiscoveri --compound--> complex
# explor --compound--> complex
# complex --compound--> ident
# ident --nsubj--> univer
# univer --conj--> hold
# desir --compound--> belong
# belong --compound--> master
# script --compound--> master
# master --nmod--> theme
# weav --compound--> theme
# theme --dobj--> univer
# narr --compound--> leav
# leav --nsubj--> reson
# last --amod--> impact
# impact --npadvmod--> leav
# reson --nsubj--> transcend
# audienc --amod--> rollspiderman
# long --amod--> rollspiderman
# credit --compound--> rollspiderman
# rollspiderman --dobj--> reson
# across --prep--> reson
# spiderver --nmod--> form
# sequel --compound--> form
# testament --compound--> anim
# power --compound--> anim
# anim --compound--> form
# art --compound--> form
# form --pobj--> across
# transcend --conj--> hold
# boundari --compound--> genr
# genr --compound--> age
# age --compound--> appeal
# appeal --compound--> film
# young --amod--> audienc
# adult --compound--> audienc
# audienc --compound--> anim
# cinemat --compound--> achiev
# achiev --compound--> anim
# rememb --compound--> anim
# landmark --compound--> anim
# anim --compound--> visionari
# storytellingin --compound--> hand
# hand --compound--> visionari
# visionari --compound--> film
# filmmak --compound--> film
# film --nsubj--> take
# take --ccomp--> transcend
# bold --amod--> risk
# risk --compound--> movi
# redefin --compound--> movi
# anim --compound--> movi
# movi --nsubj--> stand
# stand --ccomp--> take
# testament --dobj--> stand
# limitless --amod--> transport
# potenti --nmod--> transport
# storytel --compound--> anim
# abil --compound--> anim
# anim --compound--> transport
# transport --dobj--> stand
# us --appos--> transport
# world --appos--> transport
# beyond --prep--> stand
# imaginationin --amod--> conclus
# conclus --compound--> spiderman
# spiderman --pobj--> beyond
# across --prep--> stand
# spiderver --nmod--> demand
# extraordinari --compound--> demand
# cinemat --nmod--> demand
# experi --amod--> demand
# demand --pobj--> across
# see --ROOT--> see
# big --amod--> screen
# screen --compound--> anim
# possibl --compound--> anim
# triumph --compound--> anim
# anim --compound--> emot
# storytel --compound--> emot
# emot --compound--> captiv
# reson --compound--> solidifi
# solidifi --compound--> place
# place --compound--> captiv
# pantheon --nmod--> captiv
# great --amod--> captiv
# film --nmod--> stun
# stun --nmod--> captiv
# visual --amod--> captiv
# captiv --nsubj--> charact
# charact --nmod--> cinema
# profound --amod--> cinema
# theme --compound--> film
# film --compound--> testament
# testament --compound--> cinema
# power --compound--> cinema
# cinema --nsubj--> shine
# shine --compound--> exampl
# exampl --compound--> mind
# magic --compound--> achiev
# achiev --compound--> visionari
# visionari --compound--> mind
# mind --nsubj--> push
# push --ccomp--> see
# boundari --amod--> simpli
# storytel --amod--> simpli
# simpli --dobj--> push
# put --ccomp--> see
# cinemat --compound--> masterpiec
# masterpiec --compound--> age
# age --dobj--> put
#
#
# Sentence 983:
# spiderman across spiderver top tier spiderman film may well good spiderman film like compliment anim anim great anim sure make univer uniqu differ otherthi movi bring theme fate vs free beg question save peopl truli love know they will die specif way specif time even might destroy realiti mile definit say ye spiderman say question definit explor beyond spiderversethi movi origin titl spiderman beyond spiderver part expect beyond spiderver come two movi feel like one movi split two movi tri help explain see similar thing play previou spiderman movi possibl futur one movi explain find spiderman good charact find movi pretti rewatch can not wait beyond spiderver come
#
# Constituency Parse Tree:
# (S
#   spiderman/NN
#   across/IN
#   spiderver/NN
#   top/NN
#   tier/NN
#   spiderman/NN
#   film/NN
#   may/MD
#   well/RB
#   good/JJ
#   spiderman/NN
#   film/NN
#   like/IN
#   compliment/NN
#   anim/NN
#   anim/VBZ
#   great/JJ
#   anim/JJ
#   sure/JJ
#   make/VBP
#   univer/JJ
#   uniqu/JJ
#   differ/NN
#   otherthi/NN
#   movi/NN
#   bring/VBG
#   theme/JJ
#   fate/NN
#   vs/NNS
#   free/JJ
#   beg/JJ
#   question/NN
#   save/VBP
#   peopl/NN
#   truli/NN
#   love/NN
#   know/VBP
#   they/PRP
#   will/MD
#   die/VB
#   specif/JJ
#   way/NN
#   specif/JJ
#   time/NN
#   even/RB
#   might/MD
#   destroy/VB
#   realiti/NN
#   mile/JJ
#   definit/NNS
#   say/VBP
#   ye/JJ
#   spiderman/NNS
#   say/VBP
#   question/NN
#   definit/NN
#   explor/NN
#   beyond/IN
#   spiderversethi/JJ
#   movi/JJ
#   origin/NN
#   titl/NN
#   spiderman/JJ
#   beyond/IN
#   spiderver/JJ
#   part/NN
#   expect/VBP
#   beyond/IN
#   spiderver/JJ
#   come/VBP
#   two/CD
#   movi/VBP
#   feel/NNS
#   like/IN
#   one/CD
#   movi/NN
#   split/NN
#   two/CD
#   movi/NN
#   tri/NN
#   help/NN
#   explain/VB
#   see/VB
#   similar/JJ
#   thing/NN
#   play/NN
#   previou/NN
#   spiderman/NN
#   movi/NN
#   possibl/NN
#   futur/VBP
#   one/CD
#   movi/NN
#   explain/NN
#   find/IN
#   spiderman/JJ
#   good/JJ
#   charact/NN
#   find/VBP
#   movi/JJ
#   pretti/NNS
#   rewatch/NN
#   can/MD
#   not/RB
#   wait/VB
#   beyond/IN
#   spiderver/NN
#   come/VBP)
#
# Dependency Parse:
# spiderman --nsubj--> film
# across --prep--> spiderman
# spiderver --prep--> across
# top --amod--> film
# tier --compound--> spiderman
# spiderman --compound--> film
# film --pobj--> spiderver
# may --aux--> film
# well --advmod--> good
# good --amod--> film
# spiderman --compound--> film
# film --nsubj--> make
# like --prep--> film
# compliment --compound--> anim
# anim --compound--> anim
# anim --compound--> anim
# great --amod--> anim
# anim --pobj--> like
# sure --advmod--> make
# make --ROOT--> make
# univer --amod--> uniqu
# uniqu --nsubj--> differ
# differ --ccomp--> make
# otherthi --compound--> movi
# movi --nsubj--> bring
# bring --ccomp--> differ
# theme --compound--> fate
# fate --dobj--> bring
# vs --nmod--> love
# free --amod--> question
# beg --compound--> question
# question --pobj--> vs
# save --compound--> love
# peopl --compound--> love
# truli --compound--> love
# love --nsubj--> know
# know --conj--> make
# they --nsubj--> die
# will --aux--> die
# die --ccomp--> know
# specif --amod--> way
# way --npadvmod--> die
# specif --compound--> time
# time --nsubj--> destroy
# even --advmod--> destroy
# might --aux--> destroy
# destroy --advcl--> die
# realiti --compound--> mile
# mile --compound--> definit
# definit --nsubj--> say
# say --ccomp--> make
# ye --compound--> spiderman
# spiderman --nsubj--> say
# say --ccomp--> say
# question --nsubj--> expect
# definit --compound--> explor
# explor --dobj--> question
# beyond --prep--> explor
# spiderversethi --amod--> spiderman
# movi --compound--> origin
# origin --compound--> titl
# titl --compound--> spiderman
# spiderman --pobj--> beyond
# beyond --prep--> question
# spiderver --compound--> part
# part --pobj--> beyond
# expect --ccomp--> say
# beyond --prep--> expect
# spiderver --pobj--> beyond
# come --dep--> expect
# two --nummod--> movi
# movi --nsubj--> feel
# feel --ccomp--> expect
# like --mark--> split
# one --nummod--> movi
# movi --nsubj--> split
# split --advcl--> feel
# two --nummod--> movi
# movi --dobj--> split
# tri --nsubj--> help
# help --dobj--> split
# explain --xcomp--> help
# see --xcomp--> explain
# similar --amod--> thing
# thing --nsubj--> play
# play --ccomp--> see
# previou --compound--> spiderman
# spiderman --compound--> futur
# movi --compound--> futur
# possibl --compound--> futur
# futur --dobj--> play
# one --nummod--> movi
# movi --nsubj--> explain
# explain --conj--> feel
# find --xcomp--> explain
# spiderman --nmod--> charact
# good --amod--> charact
# charact --nsubj--> find
# find --ccomp--> find
# movi --compound--> rewatch
# pretti --compound--> rewatch
# rewatch --nsubj--> wait
# can --aux--> wait
# not --neg--> wait
# wait --ccomp--> find
# beyond --prep--> wait
# spiderver --pobj--> beyond
# come --punct--> make
#
#
# Sentence 984:
# begin movi high risk disappoint love good first spiderman spider ver movi howev movi exceed expect especi antagoniststhey correctli turn unintimid joke villain menac multiver threat realli feel guy problem take seriou empti fill rage mile spiderman good viewer first see realli like typic cool dark hero howev later becom major threat protagonist give audienc new set unfamiliar feel toward backstori realli allow viewer feel later explain dedic stop mile save father view twist whose side take villain movi expertli pull offi also like reintroduc origin spiderman obstacl give mile lot human problem us deal help audienc relat like time manag girl problem mani complic even throw peek gwen problem feel like issu dad deal othersth cliff hanger everyon talk feel like good sake make second sequenc movi high qualiti possibl do not know would felt movi hour long I be glad split also leave good time leave view question make excit new movieoveral movi close flawless amaz anim cinematographi everyon enjoy
#
# Constituency Parse Tree:
# (S
#   begin/VB
#   movi/RB
#   high/JJ
#   risk/NN
#   disappoint/NN
#   love/VB
#   good/JJ
#   first/JJ
#   spiderman/NN
#   spider/NN
#   ver/NN
#   movi/NN
#   howev/NN
#   movi/NN
#   exceed/VBP
#   expect/VBP
#   especi/JJ
#   antagoniststhey/JJ
#   correctli/NN
#   turn/NN
#   unintimid/JJ
#   joke/NN
#   villain/NN
#   menac/NN
#   multiver/NN
#   threat/NN
#   realli/NN
#   feel/VBP
#   guy/NN
#   problem/NN
#   take/VB
#   seriou/NN
#   empti/NN
#   fill/NN
#   rage/NN
#   mile/NN
#   spiderman/NN
#   good/JJ
#   viewer/NN
#   first/RB
#   see/VB
#   realli/NN
#   like/IN
#   typic/NN
#   cool/NN
#   dark/NN
#   hero/NN
#   howev/NN
#   later/RB
#   becom/RB
#   major/JJ
#   threat/NN
#   protagonist/NN
#   give/VBP
#   audienc/JJ
#   new/JJ
#   set/VBN
#   unfamiliar/JJ
#   feel/NN
#   toward/IN
#   backstori/FW
#   realli/FW
#   allow/VB
#   viewer/NN
#   feel/NN
#   later/RB
#   explain/VBP
#   dedic/JJ
#   stop/NN
#   mile/NN
#   save/VBP
#   father/RB
#   view/NN
#   twist/NN
#   whose/WP$
#   side/JJ
#   take/NN
#   villain/NN
#   movi/NN
#   expertli/VBP
#   pull/NN
#   offi/NN
#   also/RB
#   like/IN
#   reintroduc/NN
#   origin/VBP
#   spiderman/JJ
#   obstacl/VBP
#   give/VBP
#   mile/NN
#   lot/NN
#   human/JJ
#   problem/NN
#   us/PRP
#   deal/VB
#   help/NN
#   audienc/VB
#   relat/JJ
#   like/IN
#   time/NN
#   manag/FW
#   girl/NN
#   problem/NN
#   mani/NN
#   complic/VBD
#   even/RB
#   throw/JJ
#   peek/VBP
#   gwen/NN
#   problem/NN
#   feel/NN
#   like/IN
#   issu/JJ
#   dad/NN
#   deal/NN
#   othersth/IN
#   cliff/NN
#   hanger/NN
#   everyon/VBP
#   talk/NN
#   feel/NN
#   like/IN
#   good/JJ
#   sake/NNS
#   make/VBP
#   second/JJ
#   sequenc/NN
#   movi/NN
#   high/JJ
#   qualiti/NN
#   possibl/NNS
#   do/VBP
#   not/RB
#   know/VB
#   would/MD
#   felt/VB
#   movi/VB
#   hour/NN
#   long/RB
#   I/PRP
#   be/VB
#   glad/JJ
#   split/NN
#   also/RB
#   leave/VBP
#   good/JJ
#   time/NN
#   leave/VBP
#   view/NN
#   question/NN
#   make/VBP
#   excit/JJ
#   new/JJ
#   movieoveral/JJ
#   movi/NN
#   close/JJ
#   flawless/NN
#   amaz/NN
#   anim/NN
#   cinematographi/NN
#   everyon/NN
#   enjoy/NN)
#
# Dependency Parse:
# begin --ROOT--> begin
# movi --compound--> disappoint
# high --amod--> risk
# risk --compound--> disappoint
# disappoint --compound--> love
# love --ccomp--> begin
# good --amod--> movi
# first --amod--> movi
# spiderman --compound--> ver
# spider --compound--> ver
# ver --compound--> movi
# movi --compound--> howev
# howev --compound--> movi
# movi --dobj--> love
# exceed --aux--> expect
# expect --conj--> begin
# especi --compound--> correctli
# antagoniststhey --compound--> correctli
# correctli --nsubj--> turn
# turn --ccomp--> expect
# unintimid --compound--> menac
# joke --compound--> menac
# villain --compound--> menac
# menac --dobj--> turn
# multiver --dep--> feel
# threat --compound--> realli
# realli --nsubj--> feel
# feel --ccomp--> expect
# guy --compound--> problem
# problem --nsubj--> take
# take --ccomp--> feel
# seriou --dobj--> take
# empti --amod--> viewer
# fill --compound--> mile
# rage --compound--> mile
# mile --compound--> viewer
# spiderman --compound--> viewer
# good --amod--> viewer
# viewer --nsubj--> see
# first --advmod--> see
# see --ccomp--> expect
# realli --dobj--> see
# like --mark--> give
# typic --amod--> howev
# cool --advmod--> typic
# dark --amod--> hero
# hero --compound--> howev
# howev --nsubj--> becom
# later --advmod--> becom
# becom --nmod--> protagonist
# major --amod--> protagonist
# threat --compound--> protagonist
# protagonist --nsubj--> give
# give --advcl--> expect
# audienc --dobj--> give
# new --amod--> unfamiliar
# set --amod--> unfamiliar
# unfamiliar --amod--> audienc
# feel --dobj--> give
# toward --prep--> feel
# backstori --compound--> realli
# realli --pobj--> toward
# allow --ccomp--> expect
# viewer --compound--> feel
# feel --nsubj--> explain
# later --advmod--> explain
# explain --ccomp--> allow
# dedic --amod--> mile
# stop --compound--> mile
# mile --npadvmod--> twist
# save --amod--> father
# father --compound--> twist
# view --compound--> twist
# twist --dobj--> explain
# whose --poss--> side
# side --nsubj--> take
# take --relcl--> twist
# villain --amod--> movi
# movi --compound--> expertli
# expertli --dobj--> take
# pull --dep--> take
# offi --dobj--> pull
# also --advmod--> like
# like --prep--> take
# reintroduc --compound--> origin
# origin --compound--> spiderman
# spiderman --compound--> obstacl
# obstacl --nsubj--> give
# give --ccomp--> explain
# mile --compound--> lot
# lot --nmod--> problem
# human --amod--> problem
# problem --dobj--> give
# us --compound--> deal
# deal --appos--> problem
# help --ccomp--> explain
# audienc --compound--> relat
# relat --dobj--> help
# like --mark--> throw
# time --compound--> problem
# manag --compound--> girl
# girl --compound--> problem
# problem --compound--> complic
# mani --compound--> complic
# complic --pobj--> like
# even --advmod--> throw
# throw --advcl--> explain
# peek --compound--> problem
# gwen --compound--> problem
# problem --dobj--> throw
# feel --ccomp--> explain
# like --mark--> deal
# issu --compound--> dad
# dad --nsubj--> deal
# deal --nsubj--> make
# othersth --compound--> cliff
# cliff --dobj--> deal
# hanger --compound--> everyon
# everyon --compound--> talk
# talk --nsubj--> feel
# feel --ccomp--> deal
# like --prep--> feel
# good --amod--> sake
# sake --pobj--> like
# make --ccomp--> allow
# second --amod--> movi
# sequenc --compound--> movi
# movi --dobj--> make
# high --amod--> possibl
# qualiti --compound--> possibl
# possibl --nsubj--> know
# do --aux--> know
# not --neg--> know
# know --ccomp--> make
# would --aux--> felt
# felt --ccomp--> know
# movi --compound--> hour
# hour --npadvmod--> long
# long --advmod--> begin
# I --nsubj--> be
# be --ROOT--> be
# glad --amod--> split
# split --nsubj--> leave
# also --advmod--> leave
# leave --ccomp--> be
# good --amod--> time
# time --compound--> leave
# leave --dobj--> leave
# view --compound--> question
# question --dobj--> leave
# make --conj--> be
# excit --amod--> flawless
# new --amod--> flawless
# movieoveral --amod--> movi
# movi --nmod--> flawless
# close --amod--> flawless
# flawless --ccomp--> make
# amaz --prep--> make
# anim --compound--> cinematographi
# cinematographi --compound--> everyon
# everyon --compound--> enjoy
# enjoy --npadvmod--> be
#
#
# Sentence 985:
# spoiler free review well leave theater spiderman across spider ver wow I be speechless alway fan spider ver film expand upon everyth first spider ver film setup laugh cri smile do not think smile movi anim style somehow outdo spider ver do not even think possibl someth film go to lot peopl howev massiv cliffhang end howev give time build hype beyond spider ver anyway love movi go see
#
# Constituency Parse Tree:
# (S
#   spoiler/NN
#   free/JJ
#   review/NN
#   well/RB
#   leave/VBP
#   theater/NN
#   spiderman/NN
#   across/IN
#   spider/NN
#   ver/NN
#   wow/NN
#   I/PRP
#   be/VB
#   speechless/JJ
#   alway/RB
#   fan/JJ
#   spider/NN
#   ver/NN
#   film/NN
#   expand/VBP
#   upon/IN
#   everyth/NN
#   first/RB
#   spider/VB
#   ver/NN
#   film/NN
#   setup/NN
#   laugh/IN
#   cri/NN
#   smile/NN
#   do/VBP
#   not/RB
#   think/VB
#   smile/JJ
#   movi/NNS
#   anim/JJ
#   style/NN
#   somehow/NN
#   outdo/JJ
#   spider/NN
#   ver/NN
#   do/VBP
#   not/RB
#   even/RB
#   think/VBP
#   possibl/JJ
#   someth/NN
#   film/NN
#   go/VBP
#   to/TO
#   lot/VB
#   peopl/JJ
#   howev/NN
#   massiv/NN
#   cliffhang/JJ
#   end/NN
#   howev/NN
#   give/JJ
#   time/NN
#   build/VB
#   hype/JJ
#   beyond/IN
#   spider/NN
#   ver/NN
#   anyway/RB
#   love/VB
#   movi/NN
#   go/VB
#   see/NN)
#
# Dependency Parse:
# spoiler --compound--> review
# free --compound--> review
# review --nsubj--> leave
# well --advmod--> leave
# leave --ROOT--> leave
# theater --compound--> spiderman
# spiderman --dobj--> leave
# across --prep--> leave
# spider --compound--> ver
# ver --pobj--> across
# wow --intj--> be
# I --nsubj--> be
# be --ROOT--> be
# speechless --advmod--> alway
# alway --advmod--> expand
# fan --compound--> spider
# spider --compound--> film
# ver --compound--> film
# film --nsubj--> expand
# expand --advcl--> be
# upon --prep--> expand
# everyth --nmod--> setup
# first --amod--> setup
# spider --compound--> ver
# ver --compound--> film
# film --compound--> setup
# setup --compound--> smile
# laugh --compound--> smile
# cri --compound--> smile
# smile --pobj--> upon
# do --aux--> think
# not --neg--> think
# think --conj--> be
# smile --amod--> style
# movi --compound--> style
# anim --compound--> style
# style --nsubj--> think
# somehow --advmod--> think
# outdo --compound--> ver
# spider --compound--> ver
# ver --nsubj--> think
# do --aux--> think
# not --neg--> think
# even --advmod--> think
# think --ccomp--> think
# possibl --compound--> film
# someth --amod--> film
# film --nsubj--> go
# go --ccomp--> think
# to --prep--> go
# lot --compound--> howev
# peopl --compound--> howev
# howev --compound--> cliffhang
# massiv --compound--> cliffhang
# cliffhang --compound--> howev
# end --compound--> howev
# howev --pobj--> to
# give --advcl--> go
# time --dobj--> give
# build --dobj--> give
# hype --dobj--> build
# beyond --prep--> build
# spider --compound--> ver
# ver --pobj--> beyond
# anyway --advmod--> go
# love --compound--> movi
# movi --nsubj--> go
# go --conj--> be
# see --dep--> be
#
#
# Sentence 986:
# tri stay away trailer avoid much wow blow awayth stori good follow previou mile still struggl balanc spider life kid miss multiver friend especi gwen movi realli get go new villain call spot travel hole anywher demolish mile insult plan grow power creat abil multiver travel stori goe hard say continu spoiler thing must happen mile can not accept itth anim amaz goe along pitch perfect score twice voic quit low behind music could cinemaobvi around mile movi equal gwen movi go go lot support charact great movi genuin funnythi spoiler movi end cliffhang third movi schedul next year do not take away movi leav want good way
#
# Constituency Parse Tree:
# (S
#   tri/NN
#   stay/VB
#   away/RB
#   trailer/JJ
#   avoid/RB
#   much/JJ
#   wow/NN
#   blow/NN
#   awayth/NN
#   stori/VBD
#   good/JJ
#   follow/NN
#   previou/NN
#   mile/NN
#   still/RB
#   struggl/VBZ
#   balanc/NN
#   spider/NN
#   life/NN
#   kid/VBD
#   miss/JJ
#   multiver/NN
#   friend/NN
#   especi/VBZ
#   gwen/JJ
#   movi/NN
#   realli/NN
#   get/VB
#   go/VB
#   new/JJ
#   villain/NN
#   call/NN
#   spot/NN
#   travel/NN
#   hole/NN
#   anywher/RB
#   demolish/JJ
#   mile/NN
#   insult/NN
#   plan/NN
#   grow/VBP
#   power/NN
#   creat/NN
#   abil/NN
#   multiver/NN
#   travel/NN
#   stori/FW
#   goe/JJ
#   hard/JJ
#   say/VBP
#   continu/JJ
#   spoiler/JJ
#   thing/NN
#   must/MD
#   happen/VB
#   mile/NN
#   can/MD
#   not/RB
#   accept/VB
#   itth/JJ
#   anim/JJ
#   amaz/NN
#   goe/NN
#   along/IN
#   pitch/NN
#   perfect/NN
#   score/NN
#   twice/RB
#   voic/RB
#   quit/NN
#   low/JJ
#   behind/IN
#   music/NN
#   could/MD
#   cinemaobvi/VB
#   around/RP
#   mile/JJ
#   movi/NN
#   equal/JJ
#   gwen/NN
#   movi/NN
#   go/VBP
#   go/VB
#   lot/RB
#   support/JJ
#   charact/NN
#   great/JJ
#   movi/NN
#   genuin/NN
#   funnythi/NN
#   spoiler/NN
#   movi/JJ
#   end/NN
#   cliffhang/NN
#   third/JJ
#   movi/NN
#   schedul/NN
#   next/JJ
#   year/NN
#   do/VBP
#   not/RB
#   take/VB
#   away/RP
#   movi/NNS
#   leav/JJ
#   want/VBP
#   good/JJ
#   way/NN)
#
# Dependency Parse:
# tri --nsubj--> stay
# stay --ccomp--> say
# away --advmod--> stay
# trailer --nsubj--> avoid
# avoid --ccomp--> stay
# much --advmod--> avoid
# wow --cc--> stay
# blow --conj--> stay
# awayth --punct--> blow
# stori --nmod--> mile
# good --amod--> previou
# follow --compound--> previou
# previou --compound--> mile
# mile --nsubj--> miss
# still --advmod--> struggl
# struggl --compound--> kid
# balanc --compound--> life
# spider --compound--> life
# life --compound--> kid
# kid --nsubj--> miss
# miss --conj--> stay
# multiver --dep--> stay
# friend --nsubj--> especi
# especi --ccomp--> stay
# gwen --compound--> movi
# movi --compound--> realli
# realli --nsubj--> go
# get --aux--> go
# go --ccomp--> stay
# new --amod--> hole
# villain --compound--> spot
# call --compound--> spot
# spot --compound--> travel
# travel --compound--> hole
# hole --nsubj--> demolish
# anywher --advmod--> demolish
# demolish --amod--> plan
# mile --compound--> plan
# insult --compound--> plan
# plan --nsubj--> grow
# grow --ccomp--> go
# power --compound--> creat
# creat --compound--> abil
# abil --nsubj--> say
# multiver --nsubj--> travel
# travel --relcl--> abil
# stori --compound--> goe
# goe --dobj--> travel
# hard --advmod--> travel
# say --ROOT--> say
# continu --compound--> spoiler
# spoiler --compound--> thing
# thing --nsubj--> happen
# must --aux--> happen
# happen --ccomp--> say
# mile --npadvmod--> happen
# can --aux--> accept
# not --neg--> accept
# accept --ccomp--> say
# itth --compound--> anim
# anim --dobj--> accept
# amaz --prep--> say
# goe --pobj--> amaz
# along --prep--> goe
# pitch --nmod--> score
# perfect --amod--> score
# score --pobj--> along
# twice --advmod--> amaz
# voic --nsubj--> quit
# quit --nsubj--> cinemaobvi
# low --advmod--> quit
# behind --prep--> quit
# music --pobj--> behind
# could --aux--> cinemaobvi
# cinemaobvi --ROOT--> cinemaobvi
# around --prep--> cinemaobvi
# mile --compound--> movi
# movi --pobj--> around
# equal --amod--> movi
# gwen --compound--> movi
# movi --nsubj--> go
# go --ccomp--> cinemaobvi
# go --advcl--> go
# lot --compound--> support
# support --nsubj--> charact
# charact --ccomp--> go
# great --amod--> movi
# movi --dobj--> charact
# genuin --advmod--> funnythi
# funnythi --prep--> cinemaobvi
# spoiler --compound--> movi
# movi --nsubj--> end
# end --conj--> cinemaobvi
# cliffhang --compound--> movi
# third --compound--> movi
# movi --compound--> schedul
# schedul --dobj--> end
# next --amod--> year
# year --npadvmod--> end
# do --aux--> take
# not --neg--> take
# take --conj--> cinemaobvi
# away --advmod--> take
# movi --compound--> leav
# leav --nsubj--> want
# want --ccomp--> take
# good --amod--> way
# way --npadvmod--> want
#
#
# Sentence 987:
# let start say wow movi insan good anim movi take alreadi great anim first one somehow make even well stori know sequel be not good origin movi awesom capit blow origin water stori phenoman can not believ everyth tie togeth perfectli like web villain also great think spot great villain he funni come also intimid kind of feel bad I be super excit see happen next hope slap like movi great job sonni good like beyond spider ver
#
# Constituency Parse Tree:
# (S
#   let/VB
#   start/VB
#   say/VB
#   wow/JJ
#   movi/JJ
#   insan/JJ
#   good/JJ
#   anim/NN
#   movi/NNS
#   take/VBP
#   alreadi/JJ
#   great/JJ
#   anim/NN
#   first/RB
#   one/CD
#   somehow/NN
#   make/VB
#   even/RB
#   well/RB
#   stori/RB
#   know/VB
#   sequel/NN
#   be/VB
#   not/RB
#   good/JJ
#   origin/NN
#   movi/NN
#   awesom/NN
#   capit/NN
#   blow/VB
#   origin/JJ
#   water/NN
#   stori/JJ
#   phenoman/NN
#   can/MD
#   not/RB
#   believ/VB
#   everyth/JJ
#   tie/NN
#   togeth/VBZ
#   perfectli/NNS
#   like/IN
#   web/NN
#   villain/NN
#   also/RB
#   great/JJ
#   think/VBP
#   spot/NN
#   great/JJ
#   villain/NN
#   he/PRP
#   funni/VBZ
#   come/NN
#   also/RB
#   intimid/JJ
#   kind/NN
#   of/IN
#   feel/NN
#   bad/JJ
#   I/PRP
#   be/VB
#   super/JJ
#   excit/NN
#   see/VBP
#   happen/JJ
#   next/IN
#   hope/NN
#   slap/VBP
#   like/IN
#   movi/NN
#   great/JJ
#   job/NN
#   sonni/RB
#   good/JJ
#   like/IN
#   beyond/IN
#   spider/NN
#   ver/NN)
#
# Dependency Parse:
# let --advcl--> make
# start --nsubj--> say
# say --ccomp--> let
# wow --intj--> let
# movi --nmod--> movi
# insan --amod--> movi
# good --compound--> anim
# anim --compound--> movi
# movi --nsubj--> take
# take --ccomp--> let
# alreadi --nmod--> anim
# great --amod--> anim
# anim --dobj--> take
# first --amod--> one
# one --nsubj--> make
# somehow --advmod--> make
# make --ROOT--> make
# even --advmod--> well
# well --advmod--> know
# stori --nsubj--> know
# know --compound--> sequel
# sequel --nsubj--> be
# be --ccomp--> make
# not --neg--> be
# good --amod--> movi
# origin --compound--> movi
# movi --compound--> phenoman
# awesom --compound--> capit
# capit --compound--> phenoman
# blow --compound--> origin
# origin --compound--> phenoman
# water --compound--> stori
# stori --compound--> phenoman
# phenoman --nsubj--> believ
# can --aux--> believ
# not --neg--> believ
# believ --prep--> be
# everyth --nsubj--> tie
# tie --ccomp--> make
# togeth --compound--> perfectli
# perfectli --dobj--> tie
# like --prep--> perfectli
# web --compound--> villain
# villain --pobj--> like
# also --advmod--> great
# great --amod--> think
# think --compound--> spot
# spot --compound--> villain
# great --amod--> villain
# villain --dobj--> tie
# he --nsubj--> come
# funni --appos--> he
# come --ccomp--> make
# also --advmod--> come
# intimid --advcl--> come
# kind --advmod--> of
# of --advmod--> feel
# feel --advcl--> come
# bad --acomp--> feel
# I --nsubj--> be
# be --ROOT--> be
# super --amod--> excit
# excit --nsubj--> see
# see --parataxis--> be
# happen --xcomp--> see
# next --amod--> slap
# hope --compound--> slap
# slap --dep--> be
# like --prep--> slap
# movi --nmod--> sonni
# great --amod--> job
# job --compound--> sonni
# sonni --compound--> good
# good --acomp--> be
# like --prep--> good
# beyond --prep--> good
# spider --compound--> ver
# ver --pobj--> beyond
#
#
# Sentence 988:
# spiderman across spiderver amaz movi absolut love let tell surpass expect incred visual heartfelt stori movi hook begin endth anim stun color bright art style cool action scene realli excit feel like your watch comic book come life cool see attent detail realli impress everi part movi look incrediblebut way look that great stori fantast follow journey mile moral confid hero time around movi good mix funni moment emot part thrill action come togeth tell realli interest engag stori plu introduc new charact make spiderver even interestingth music movi also realli good song choose fit perfectli what happen screen make movi even excit help feel involv actionfor we indian spiderman call pavitra prabhakar karan soni littl give short tour bombaythi movi may primarili target young audienc find stori fastpac quit complex result believ might pose challeng kid fulli comprehend follow alongnoteit first review site
#
# Constituency Parse Tree:
# (S
#   spiderman/NN
#   across/IN
#   spiderver/NN
#   amaz/NN
#   movi/NN
#   absolut/IN
#   love/JJ
#   let/NN
#   tell/VB
#   surpass/VB
#   expect/VB
#   incred/JJ
#   visual/JJ
#   heartfelt/NN
#   stori/NN
#   movi/NN
#   hook/NN
#   begin/VBP
#   endth/JJ
#   anim/NN
#   stun/NN
#   color/NN
#   bright/JJ
#   art/NN
#   style/NN
#   cool/JJ
#   action/NN
#   scene/NN
#   realli/VBP
#   excit/JJ
#   feel/NN
#   like/IN
#   your/PRP$
#   watch/NN
#   comic/JJ
#   book/NN
#   come/VBP
#   life/NN
#   cool/NN
#   see/VBP
#   attent/JJ
#   detail/NN
#   realli/NN
#   impress/NN
#   everi/IN
#   part/NN
#   movi/NN
#   look/NN
#   incrediblebut/JJ
#   way/NN
#   look/NN
#   that/IN
#   great/JJ
#   stori/JJ
#   fantast/NN
#   follow/JJ
#   journey/NN
#   mile/NN
#   moral/JJ
#   confid/NN
#   hero/NN
#   time/NN
#   around/IN
#   movi/RB
#   good/JJ
#   mix/NN
#   funni/JJ
#   moment/NN
#   emot/IN
#   part/NN
#   thrill/NN
#   action/NN
#   come/VB
#   togeth/NN
#   tell/NN
#   realli/VB
#   interest/NN
#   engag/NN
#   stori/FW
#   plu/NN
#   introduc/VBP
#   new/JJ
#   charact/JJ
#   make/VBP
#   spiderver/JJ
#   even/RB
#   interestingth/VBP
#   music/NN
#   movi/NN
#   also/RB
#   realli/RB
#   good/JJ
#   song/NN
#   choose/JJ
#   fit/NN
#   perfectli/NN
#   what/WP
#   happen/VBZ
#   screen/JJ
#   make/VBP
#   movi/JJ
#   even/RB
#   excit/VBP
#   help/NN
#   feel/VB
#   involv/JJ
#   actionfor/IN
#   we/PRP
#   indian/JJ
#   spiderman/NN
#   call/NN
#   pavitra/NN
#   prabhakar/NN
#   karan/VBD
#   soni/JJ
#   littl/JJ
#   give/VB
#   short/JJ
#   tour/NN
#   bombaythi/NN
#   movi/NN
#   may/MD
#   primarili/VB
#   target/NN
#   young/JJ
#   audienc/JJ
#   find/VB
#   stori/JJ
#   fastpac/JJ
#   quit/NN
#   complex/JJ
#   result/NN
#   believ/NN
#   might/MD
#   pose/VB
#   challeng/JJ
#   kid/NN
#   fulli/JJ
#   comprehend/NN
#   follow/NN
#   alongnoteit/IN
#   first/JJ
#   review/NN
#   site/NN)
#
# Dependency Parse:
# spiderman --nsubj--> let
# across --prep--> spiderman
# spiderver --prep--> spiderman
# amaz --advmod--> absolut
# movi --compound--> absolut
# absolut --appos--> spiderman
# love --appos--> spiderman
# let --ROOT--> let
# tell --compound--> surpass
# surpass --nsubj--> expect
# expect --ccomp--> let
# incred --amod--> hook
# visual --amod--> stori
# heartfelt --amod--> stori
# stori --compound--> movi
# movi --compound--> hook
# hook --nsubj--> begin
# begin --ccomp--> expect
# endth --amod--> scene
# anim --compound--> stun
# stun --nmod--> color
# color --nmod--> style
# bright --amod--> art
# art --compound--> style
# style --nmod--> scene
# cool --amod--> scene
# action --compound--> scene
# scene --compound--> excit
# realli --compound--> excit
# excit --nsubj--> feel
# feel --ccomp--> begin
# like --mark--> come
# your --poss--> book
# watch --nmod--> book
# comic --amod--> book
# book --nsubj--> come
# come --advcl--> feel
# life --npadvmod--> cool
# cool --advcl--> come
# see --parataxis--> come
# attent --compound--> detail
# detail --compound--> realli
# realli --nsubj--> impress
# impress --compound--> movi
# everi --amod--> movi
# part --compound--> movi
# movi --nsubj--> look
# look --conj--> come
# incrediblebut --amod--> way
# way --npadvmod--> look
# look --dep--> let
# that --det--> journey
# great --amod--> fantast
# stori --compound--> fantast
# fantast --compound--> journey
# follow --compound--> journey
# journey --nsubjpass--> time
# mile --appos--> journey
# moral --amod--> time
# confid --amod--> hero
# hero --compound--> time
# time --nsubj--> emot
# around --prep--> time
# movi --nmod--> moment
# good --amod--> mix
# mix --compound--> moment
# funni --compound--> moment
# moment --pobj--> around
# emot --nsubj--> tell
# part --nmod--> action
# thrill --compound--> action
# action --dobj--> emot
# come --npadvmod--> emot
# togeth --npadvmod--> come
# tell --ccomp--> let
# realli --compound--> engag
# interest --compound--> engag
# engag --compound--> stori
# stori --compound--> introduc
# plu --compound--> introduc
# introduc --dobj--> tell
# new --amod--> charact
# charact --nsubj--> make
# make --ccomp--> tell
# spiderver --intj--> make
# even --advmod--> movi
# interestingth --compound--> movi
# music --compound--> movi
# movi --pobj--> spiderver
# also --advmod--> realli
# realli --ccomp--> make
# good --amod--> song
# song --dobj--> realli
# choose --conj--> make
# fit --compound--> perfectli
# perfectli --dobj--> choose
# what --nsubj--> happen
# happen --csubj--> make
# screen --nsubj--> make
# make --ccomp--> choose
# movi --nsubj--> excit
# even --advmod--> excit
# excit --ccomp--> make
# help --dobj--> excit
# feel --ccomp--> make
# involv --acomp--> feel
# actionfor --mark--> give
# we --nsubj--> call
# indian --amod--> spiderman
# spiderman --appos--> we
# call --compound--> prabhakar
# pavitra --compound--> prabhakar
# prabhakar --compound--> littl
# karan --compound--> littl
# soni --compound--> littl
# littl --nsubj--> give
# give --advcl--> feel
# short --amod--> movi
# tour --compound--> bombaythi
# bombaythi --compound--> movi
# movi --dobj--> give
# may --aux--> find
# primarili --amod--> audienc
# target --nmod--> audienc
# young --amod--> audienc
# audienc --nsubj--> find
# find --ccomp--> make
# stori --compound--> fastpac
# fastpac --nsubj--> quit
# quit --ccomp--> find
# complex --amod--> result
# result --compound--> believ
# believ --nsubj--> pose
# might --aux--> pose
# pose --ccomp--> quit
# challeng --compound--> fulli
# kid --compound--> fulli
# fulli --nsubj--> comprehend
# comprehend --ccomp--> pose
# follow --compound--> site
# alongnoteit --dobj--> follow
# first --amod--> review
# review --compound--> site
# site --dobj--> comprehend
#
#
# Sentence 989:
# good movieth good movi see entir lifeit exict beauti sad scenesand second silenc mile say mom I be spiderman second silenc who spiderman fake end liter scream mile glich tought wrong univer whole cinema scream gwen say he wrong univer uncl aaron show crazyth scene show univer miless dad die start cri sad crazi scene turn mile prowler universei leave cinema trembl leg wait next movi
#
# Constituency Parse Tree:
# (S
#   good/JJ
#   movieth/NNS
#   good/JJ
#   movi/NNS
#   see/VBP
#   entir/JJ
#   lifeit/FW
#   exict/NN
#   beauti/NN
#   sad/JJ
#   scenesand/NN
#   second/JJ
#   silenc/NN
#   mile/NNS
#   say/VBP
#   mom/NN
#   I/PRP
#   be/VB
#   spiderman/JJ
#   second/JJ
#   silenc/NN
#   who/WP
#   spiderman/VBD
#   fake/JJ
#   end/NN
#   liter/NN
#   scream/NN
#   mile/NN
#   glich/JJ
#   tought/NN
#   wrong/JJ
#   univer/JJ
#   whole/JJ
#   cinema/NN
#   scream/NN
#   gwen/NNS
#   say/VBP
#   he/PRP
#   wrong/JJ
#   univer/JJ
#   uncl/JJ
#   aaron/NN
#   show/NN
#   crazyth/JJ
#   scene/NN
#   show/NN
#   univer/JJ
#   miless/NN
#   dad/NN
#   die/JJ
#   start/NN
#   cri/NN
#   sad/JJ
#   crazi/JJ
#   scene/NN
#   turn/VBP
#   mile/JJ
#   prowler/NN
#   universei/NN
#   leave/VBP
#   cinema/NN
#   trembl/NN
#   leg/NN
#   wait/VBP
#   next/JJ
#   movi/NN)
#
# Dependency Parse:
# good --amod--> movieth
# movieth --compound--> movi
# good --amod--> movi
# movi --nsubj--> see
# see --ccomp--> say
# entir --amod--> exict
# lifeit --compound--> exict
# exict --ccomp--> see
# beauti --nmod--> scenesand
# sad --compound--> scenesand
# scenesand --compound--> second
# second --amod--> mile
# silenc --compound--> mile
# mile --npadvmod--> say
# say --ccomp--> see
# mom --npadvmod--> be
# I --nsubj--> be
# be --ccomp--> say
# spiderman --amod--> silenc
# second --amod--> silenc
# silenc --attr--> be
# who --nsubj--> spiderman
# spiderman --relcl--> silenc
# fake --amod--> scream
# end --compound--> scream
# liter --compound--> scream
# scream --compound--> glich
# mile --compound--> glich
# glich --dobj--> spiderman
# tought --advmod--> univer
# wrong --advmod--> univer
# univer --ccomp--> say
# whole --amod--> gwen
# cinema --compound--> scream
# scream --compound--> gwen
# gwen --nsubj--> say
# say --ROOT--> say
# he --compound--> wrong
# wrong --nsubj--> univer
# univer --ccomp--> say
# uncl --advmod--> univer
# aaron --compound--> show
# show --dep--> univer
# crazyth --compound--> scene
# scene --nsubj--> show
# show --ccomp--> show
# univer --amod--> dad
# miless --compound--> dad
# dad --nsubj--> die
# die --parataxis--> univer
# start --compound--> cri
# cri --nmod--> scene
# sad --amod--> scene
# crazi --compound--> scene
# scene --nsubj--> turn
# turn --ccomp--> say
# mile --compound--> prowler
# prowler --compound--> universei
# universei --nsubj--> leave
# leave --compound--> leg
# cinema --compound--> leg
# trembl --compound--> leg
# leg --compound--> wait
# wait --dobj--> turn
# next --amod--> movi
# movi --npadvmod--> wait
#
#
# Sentence 990:
# movi thrill amaz go to make cri laugh get roller coaster make feel good happi secret end go to end cliff note apart holi f can not get enough watch movi especi love first one start grip your do can not stop watch everi time watch can not wait see happen next part hope bring asapcan believ even mani spiderman charact like million univer alway still abl amaz charact develop almost that call good direct keep do not let strike destroy franchis plea
#
# Constituency Parse Tree:
# (S
#   movi/NN
#   thrill/NN
#   amaz/RB
#   go/VBP
#   to/TO
#   make/VB
#   cri/NN
#   laugh/IN
#   get/NN
#   roller/NN
#   coaster/NN
#   make/VBP
#   feel/NN
#   good/JJ
#   happi/NN
#   secret/JJ
#   end/NN
#   go/VBP
#   to/TO
#   end/VB
#   cliff/JJ
#   note/NN
#   apart/RB
#   holi/VBZ
#   f/NNS
#   can/MD
#   not/RB
#   get/VB
#   enough/JJ
#   watch/NN
#   movi/NN
#   especi/NN
#   love/IN
#   first/JJ
#   one/CD
#   start/NN
#   grip/VB
#   your/PRP$
#   do/NNS
#   can/MD
#   not/RB
#   stop/VB
#   watch/NN
#   everi/JJ
#   time/NN
#   watch/NN
#   can/MD
#   not/RB
#   wait/VB
#   see/VB
#   happen/JJ
#   next/JJ
#   part/NN
#   hope/VBP
#   bring/VBG
#   asapcan/JJ
#   believ/NN
#   even/RB
#   mani/RBR
#   spiderman/JJ
#   charact/NN
#   like/IN
#   million/CD
#   univer/JJ
#   alway/RB
#   still/RB
#   abl/JJ
#   amaz/NNS
#   charact/NN
#   develop/VB
#   almost/RB
#   that/IN
#   call/NN
#   good/JJ
#   direct/JJ
#   keep/VB
#   do/VBP
#   not/RB
#   let/VB
#   strike/NN
#   destroy/VB
#   franchis/JJ
#   plea/NN)
#
# Dependency Parse:
# movi --compound--> thrill
# thrill --nsubj--> go
# amaz --advmod--> go
# go --ROOT--> go
# to --aux--> make
# make --advcl--> go
# cri --nsubj--> laugh
# laugh --nsubj--> get
# get --ccomp--> make
# roller --compound--> coaster
# coaster --dobj--> get
# make --advcl--> go
# feel --ccomp--> make
# good --amod--> happi
# happi --dobj--> feel
# secret --amod--> end
# end --nsubj--> go
# go --ccomp--> feel
# to --prep--> go
# end --compound--> note
# cliff --compound--> note
# note --pobj--> to
# apart --punct--> go
# holi --compound--> f
# f --nsubj--> get
# can --aux--> get
# not --neg--> get
# get --ROOT--> get
# enough --amod--> watch
# watch --dobj--> get
# movi --nsubj--> especi
# especi --acl--> watch
# love --conj--> get
# first --advmod--> love
# one --nummod--> grip
# start --compound--> grip
# grip --dobj--> love
# your --poss--> do
# do --nsubj--> stop
# can --aux--> stop
# not --neg--> stop
# stop --conj--> get
# watch --xcomp--> stop
# everi --amod--> watch
# time --compound--> watch
# watch --nsubj--> wait
# can --aux--> wait
# not --neg--> wait
# wait --conj--> get
# see --intj--> happen
# happen --xcomp--> wait
# next --amod--> hope
# part --compound--> hope
# hope --nsubj--> bring
# bring --nsubj--> univer
# asapcan --compound--> believ
# believ --dobj--> bring
# even --advmod--> spiderman
# mani --compound--> spiderman
# spiderman --compound--> charact
# charact --appos--> believ
# like --prep--> charact
# million --pobj--> like
# univer --dep--> get
# alway --advmod--> univer
# still --advmod--> abl
# abl --advcl--> univer
# amaz --advmod--> charact
# charact --nsubj--> develop
# develop --conj--> get
# almost --advmod--> that
# that --nsubj--> call
# call --ccomp--> develop
# good --amod--> keep
# direct --amod--> keep
# keep --dobj--> call
# do --aux--> let
# not --neg--> let
# let --conj--> get
# strike --nsubj--> destroy
# destroy --ccomp--> let
# franchis --det--> plea
# plea --dobj--> destroy
#
#
# Sentence 991:
# love movi much like sjsjkdkabdjd honestli do not understand anybodi could hate plot interest there mani twist cliffhang oh gosh whole movi face like lol everyth movi amaz charact visual soundtrack everythingggg bro walk movi theater chang mind whole time seat grip arm rest inten movi mention mani cool charact like omg movi disappoint anyway love movi much I be obsess like plea help omg anyway can not wait part I be excit
#
# Constituency Parse Tree:
# (S
#   love/VB
#   movi/RB
#   much/JJ
#   like/IN
#   sjsjkdkabdjd/NN
#   honestli/NNS
#   do/VBP
#   not/RB
#   understand/VB
#   anybodi/NN
#   could/MD
#   hate/VB
#   plot/JJ
#   interest/NN
#   there/RB
#   mani/JJ
#   twist/NN
#   cliffhang/NN
#   oh/IN
#   gosh/JJ
#   whole/JJ
#   movi/NN
#   face/NN
#   like/IN
#   lol/JJ
#   everyth/FW
#   movi/FW
#   amaz/FW
#   charact/JJ
#   visual/JJ
#   soundtrack/NN
#   everythingggg/NN
#   bro/NN
#   walk/VBP
#   movi/NN
#   theater/NN
#   chang/NN
#   mind/IN
#   whole/JJ
#   time/NN
#   seat/NN
#   grip/NN
#   arm/NN
#   rest/NN
#   inten/NN
#   movi/JJ
#   mention/NN
#   mani/NN
#   cool/JJ
#   charact/NN
#   like/IN
#   omg/JJ
#   movi/NN
#   disappoint/NN
#   anyway/RB
#   love/VB
#   movi/RB
#   much/JJ
#   I/PRP
#   be/VB
#   obsess/VBN
#   like/IN
#   plea/NN
#   help/NN
#   omg/VB
#   anyway/RB
#   can/MD
#   not/RB
#   wait/VB
#   part/NN
#   I/PRP
#   be/VB
#   excit/JJ)
#
# Dependency Parse:
# love --nsubj--> understand
# movi --dobj--> love
# much --advmod--> like
# like --prep--> love
# sjsjkdkabdjd --compound--> honestli
# honestli --pobj--> like
# do --aux--> understand
# not --neg--> understand
# understand --csubj--> hate
# anybodi --dobj--> understand
# could --aux--> hate
# hate --ROOT--> hate
# plot --compound--> interest
# interest --dobj--> hate
# there --advmod--> interest
# mani --compound--> twist
# twist --compound--> cliffhang
# cliffhang --punct--> hate
# oh --intj--> whole
# gosh --intj--> oh
# whole --amod--> movi
# movi --nsubj--> face
# face --nmod--> movi
# like --prep--> face
# lol --compound--> movi
# everyth --compound--> movi
# movi --pobj--> like
# amaz --advmod--> bro
# charact --amod--> bro
# visual --amod--> soundtrack
# soundtrack --compound--> everythingggg
# everythingggg --compound--> bro
# bro --appos--> movi
# walk --compound--> movi
# movi --compound--> theater
# theater --compound--> chang
# chang --nsubj--> mind
# mind --dobj--> face
# whole --amod--> time
# time --compound--> rest
# seat --compound--> grip
# grip --compound--> rest
# arm --compound--> rest
# rest --compound--> movi
# inten --compound--> movi
# movi --nsubj--> mention
# mention --ROOT--> mention
# mani --nmod--> charact
# cool --amod--> charact
# charact --dobj--> mention
# like --prep--> charact
# omg --compound--> movi
# movi --compound--> disappoint
# disappoint --pobj--> like
# anyway --advmod--> mention
# love --ccomp--> mention
# movi --dobj--> love
# much --advmod--> mention
# I --nsubj--> be
# be --ccomp--> mention
# obsess --acomp--> be
# like --prep--> obsess
# plea --compound--> help
# help --compound--> omg
# omg --pobj--> like
# anyway --advmod--> be
# can --aux--> wait
# not --neg--> wait
# wait --advcl--> mention
# part --dobj--> wait
# I --nsubj--> be
# be --relcl--> part
# excit --acomp--> be
#
#
# Sentence 992:
# amaz anim movi prolongedth movi two half hour long understand do not proper end denouement movi kind of prolongedmayb cinema could comfort watch home first part last one would opportun paus think etcso say anim work hard perceiv analyz time realli good way anim indescrib amaz differ variou
#
# Constituency Parse Tree:
# (S
#   amaz/NN
#   anim/NN
#   movi/NN
#   prolongedth/JJ
#   movi/NN
#   two/CD
#   half/NN
#   hour/NN
#   long/JJ
#   understand/NN
#   do/VBP
#   not/RB
#   proper/VB
#   end/NN
#   denouement/NN
#   movi/NN
#   kind/NN
#   of/IN
#   prolongedmayb/NN
#   cinema/NN
#   could/MD
#   comfort/VB
#   watch/VB
#   home/NN
#   first/RB
#   part/NN
#   last/JJ
#   one/CD
#   would/MD
#   opportun/VB
#   paus/JJ
#   think/NN
#   etcso/NNS
#   say/VBP
#   anim/JJ
#   work/NN
#   hard/JJ
#   perceiv/NN
#   analyz/NN
#   time/NN
#   realli/VB
#   good/JJ
#   way/NN
#   anim/IN
#   indescrib/NN
#   amaz/NN
#   differ/NN
#   variou/NN)
#
# Dependency Parse:
# amaz --advmod--> understand
# anim --compound--> movi
# movi --compound--> movi
# prolongedth --compound--> movi
# movi --nsubj--> understand
# two --nummod--> hour
# half --quantmod--> two
# hour --npadvmod--> long
# long --amod--> understand
# understand --nsubj--> opportun
# do --aux--> watch
# not --neg--> kind
# proper --amod--> kind
# end --compound--> kind
# denouement --amod--> movi
# movi --compound--> kind
# kind --nsubj--> watch
# of --prep--> kind
# prolongedmayb --compound--> cinema
# cinema --pobj--> of
# could --aux--> watch
# comfort --compound--> watch
# watch --xcomp--> understand
# home --advmod--> watch
# first --amod--> part
# part --npadvmod--> watch
# last --amod--> one
# one --nsubj--> opportun
# would --aux--> opportun
# opportun --ROOT--> opportun
# paus --nsubj--> think
# think --ccomp--> opportun
# etcso --nsubj--> say
# say --ccomp--> think
# anim --compound--> work
# work --nsubj--> time
# hard --compound--> perceiv
# perceiv --nmod--> time
# analyz --amod--> time
# time --compound--> indescrib
# realli --nmod--> way
# good --amod--> way
# way --compound--> indescrib
# anim --compound--> indescrib
# indescrib --nsubj--> differ
# amaz --advmod--> differ
# differ --ccomp--> say
# variou --dobj--> differ
#
#
# Sentence 993:
# watch film last night omg good cinemat experi ever great pictur comedi action pack good cliff hanger I have see life definit recommend spider man fan anoth reason good film go cast fantast charact also come film late do not think film would well first well way home opinion anoth reason think film good even though villan do not much screen time play part well
#
# Constituency Parse Tree:
# (S
#   watch/NN
#   film/NN
#   last/JJ
#   night/NN
#   omg/RB
#   good/JJ
#   cinemat/NN
#   experi/NN
#   ever/RB
#   great/JJ
#   pictur/NN
#   comedi/NN
#   action/NN
#   pack/RB
#   good/JJ
#   cliff/NN
#   hanger/NN
#   I/PRP
#   have/VBP
#   see/VBN
#   life/NN
#   definit/NN
#   recommend/JJ
#   spider/NN
#   man/NN
#   fan/NN
#   anoth/JJ
#   reason/NN
#   good/JJ
#   film/NN
#   go/VBP
#   cast/NN
#   fantast/NN
#   charact/NN
#   also/RB
#   come/VBP
#   film/NN
#   late/RB
#   do/VBP
#   not/RB
#   think/VB
#   film/NN
# ...
#   ever/RB
#   fck/RB
#   movi/JJ
#   third/JJ
#   anim/JJ
#   style/NN
#   across/IN
#   spiderver/NN
#   somewhat/RB
#   differ/JJ
#   anim/JJ
#   style/NN
#   spiderver/NN
#   scene/NN
#   anim/NN
#   spiderver/NN
#   almost/RB
#   photorealist/JJ
#   anim/JJ
#   across/IN
#   spiderver/NN
#   often/RB
#   almost/RB
#   impressionist/JJ
#   film/NN
#   featur/NN
#   beauti/NN
#   detail/NN
#   background/NN
#   fourth/JJ
#   would/MD
#   not/RB
#   go/VB
#   far/RB
#   say/VBP
#   across/IN
#   spiderver/RB
#   well/RB
#   film/NN
#   spiderver/NN
#   think/VBP
#   theyr/JJ
#   equal/JJ
#   impress/NN
#   though/IN
#   across/IN
#   spiderver/NN
#   perhap/NN
#   excit/NN
#   film/NN
#   fifth/JJ
#   peopl/NN
#   auditorium/NN
#   get/VBP
#   see/VB
#   anim/JJ
#   film/NN
#   adult/NN
#   latetwenti/NN
#   thirti/NN
#   earlyfourti/VBP
#   old/JJ
#   peopl/NN
#   enjoy/NN
#   see/VBP
#   film/NN
#   lot/NN
#   go/VBP
#   similar/JJ
#   peculiar/NN
#   experi/NN
#   watch/NN
#   titan/NN
#   theater/NN
#   februari/JJ
#   year/NN
#   peopl/NN
#   auditorium/NN
#   woman/NN
#   mostli/NN
#   young/JJ
#   woman/NN
#   truli/NN
#   excit/VBD
#   even/RB
#   cri/JJ
#   time/NN
#   film/NN
#   come/VBP
#   end/NN
#   credit/NN
#   begin/VBP
#   roll/JJ
#   member/NN
#   fair/JJ
#   sex/NN
#   begin/NN
#   talk/NN
#   excitedli/IN
#   film/NN
#   say/VBP
#   jame/NN
#   cameron/NN
#   know/VBP
#   make/VBP
#   film/NN
#   appeal/NN
#   man/NN
#   woman/NN
#   wonder/VBP
#   film/NN
#   bring/NN
#   much/JJ
#   cash/NN
#   sixth/NNS
#   see/VBP
#   across/IN
#   spiderver/NN
#   later/RB
#   make/VBP
#   spend/JJ
#   half/JJ
#   day/NN
#   watch/VB
#   spiderver/NN
#   video/NN
#   watch/NN
#   scene/NN
#   sever/NN
#   time/NN
#   often/RB
#   paus/JJ
#   movi/NNS
#   order/NN
#   look/VBP
#   background/IN
#   charact/JJ
#   design/NN
#   true/JJ
#   gwen/NN
#   staci/NN
#   sometim/JJ
#   move/NN
#   like/IN
#   ballet/NN
#   dancer/NN
#   film/NN
#   watch/NN
#   across/IN
#   spidervers/NNS
#   bare/VBP
#   know/JJ
#   anyth/NN
#   phil/NN
#   lord/NN
#   christoph/VBZ
#   miller/JJ
#   interest/NN
#   filmmak/NN
#   do/VBP
#   take/VB
#   look/VB
#   filmographi/JJ
#   turn/NN
#   work/NN
#   sever/RB
#   film/NN
#   like/IN
#   quit/NN
#   lot/NN
#   get/VB
#   see/VBN
#   film/NN
#   theater/NN)
#
# Dependency Parse:
# briefli --nsubj--> review
# review --ccomp--> say
# spiderman --dobj--> review
# spiderver --prep--> review
# one --nummod--> post
# post --pobj--> spiderver
# soon --advmod--> relea
# relea --amod--> theater
# theater --pobj--> spiderver
# seem --ccomp--> review
# peopl --nsubj--> get
# get --ccomp--> seem
# idea --dobj--> get
# do --aux--> like
# not --neg--> like
# like --prep--> review
# film --compound--> case
# case --nsubj--> go
# go --ccomp--> like
# see --advcl--> go
# film --compound--> time
# time --nsubj--> play
# play --ccomp--> see
# theater --compound--> video
# video --dobj--> play
# even --advmod--> soundtrack
# soundtrack --ccomp--> like
# like --prep--> soundtrack
# incred --amod--> year
# relea --compound--> year
# year --compound--> slightli
# slightli --compound--> spiderver
# spiderver --nsubj--> think
# do --aux--> think
# not --neg--> think
# think --conj--> review
# spiderver --mark--> think
# good --amod--> spiderman
# spiderman --compound--> movi
# movi --nmod--> movi
# good --amod--> superhero
# superhero --compound--> movi
# movi --nsubj--> think
# ever --advmod--> think
# think --ccomp--> think
# spiderman --nsubj--> say
# still --advmod--> good
# good --amod--> movi
# spiderman --compound--> movi
# movi --appos--> spiderman
# ever --advmod--> say
# would --aux--> say
# say --ccomp--> think
# spiderver --intj--> say
# incred --amod--> replay
# replay --pobj--> spiderver
# valu --compound--> someth
# someth --nsubj--> say
# can --aux--> say
# not --neg--> say
# say --ccomp--> say
# mani --compound--> film
# film --nsubj--> make
# get --aux--> make
# make --ccomp--> say
# last --amod--> watch
# two --nummod--> watch
# even --advmod--> three
# three --nummod--> watch
# decad --compound--> watch
# watch --nsubj--> feel
# spiderver --prep--> feel
# first --amod--> time
# time --pobj--> spiderver
# feel --ccomp--> make
# someth --nsubj--> quit
# quit --ccomp--> feel
# right --advmod--> quit
# although --mark--> perhap
# alreadi --nmod--> film
# realiz --nmod--> film
# special --amod--> film
# film --nsubj--> perhap
# spiderver --prep--> film
# featur --amod--> scene
# number --compound--> inspir
# inspir --compound--> scene
# scene --compound--> appeal
# appeal --compound--> anim
# detail --compound--> anim
# anim --pobj--> spiderver
# rather --advmod--> epic
# epic --amod--> character
# stori --nmod--> character
# good --amod--> character
# character --compound--> detail
# mani --nmod--> detail
# neat --amod--> detail
# detail --appos--> anim
# still --advmod--> perhap
# perhap --advcl--> feel
# main --amod--> charact
# charact --dobj--> perhap
# appeal --conj--> feel
# back --advmod--> appeal
# peter --compound--> b
# b --compound--> parker
# parker --nsubj--> relat
# could --aux--> relat
# relat --ccomp--> say
# charact --dobj--> relat
# way --compound--> know
# know --npadvmod--> relat
# mile --npadvmod--> appeal
# moral --amod--> film
# who --nsubj--> main
# main --amod--> film
# main --amod--> film
# charact --compound--> film
# film --nsubj--> appeal
# do --aux--> appeal
# not --neg--> appeal
# appeal --advcl--> relat
# way --npadvmod--> appeal
# do --aux--> know
# not --neg--> know
# even --advmod--> know
# know --ccomp--> say
# mile --nmod--> role
# moral --amod--> film
# watch --compound--> film
# film --compound--> role
# film --compound--> role
# mile --compound--> play
# play --compound--> role
# role --dobj--> know
# come --ccomp--> say
# relief --compound--> end
# end --nsubj--> get
# get --ccomp--> say
# anyth --dobj--> get
# heroic --advmod--> get
# there --expl--> fact
# also --advmod--> fact
# fact --nsubj--> happen
# spiderver --prep--> fact
# kinet --compound--> film
# film --pobj--> spiderver
# almost --advmod--> everyth
# everyth --appos--> film
# happen --advcl--> say
# fast --amod--> therefor
# therefor --nsubj--> see
# see --advcl--> happen
# order --compound--> viewer
# viewer --nsubj--> understand
# understand --ccomp--> see
# notic --compound--> everyth
# everyth --nsubj--> happen
# happen --ccomp--> understand
# see --ccomp--> say
# spiderver --prep--> see
# first --amod--> time
# time --pobj--> spiderver
# new --amod--> experi
# somewhat --advmod--> odd
# odd --amod--> experi
# experi --nsubj--> realli
# do --aux--> realli
# not --neg--> realli
# realli --nsubj--> find
# find --advcl--> review
# main --amod--> howev
# charact --compound--> howev
# truli --amod--> howev
# appeal --compound--> howev
# howev --nsubj--> see
# see --ccomp--> find
# across --prep--> see
# spiderver --compound--> theater
# theater --pobj--> across
# make --dep--> review
# like --intj--> make
# spiderver --intj--> make
# even --advmod--> alreadi
# alreadi --nmod--> staci
# first --amod--> mile
# mile --nmod--> staci
# moral --amod--> staci
# gwen --compound--> staci
# staci --nsubj--> develop
# get --aux--> develop
# charact --nsubj--> develop
# develop --ccomp--> make
# across --prep--> develop
# spiderver --nmod--> turn
# thu --compound--> turn
# turn --nmod--> alreadi
# appeal --amod--> alreadi
# charact --amod--> alreadi
# second --amod--> peopl
# mani --compound--> peopl
# peopl --compound--> alreadi
# especi --nmod--> alreadi
# young --amod--> alreadi
# man --compound--> alreadi
# alreadi --nsubj--> express
# express --ccomp--> make
# sweet --amod--> love
# hard --amod--> love
# love --dobj--> express
# across --prep--> love
# spiderver --prep--> express
# especi --compound--> call
# gwen --compound--> staci
# staci --compound--> call
# internet --compound--> call
# call --npadvmod--> across
# across --prep--> express
# spiderver --nmod--> thing
# good --amod--> thing
# thing --pobj--> across
# ever --advmod--> good
# good --amod--> guy
# guy --nsubj--> share
# do --aux--> share
# not --neg--> share
# share --conj--> review
# euphoria --compound--> perhap
# perhap --dobj--> share
# I --nsubj--> be
# be --conj--> review
# littl --compound--> knowledg
# knowledg --compound--> review
# therefor --compound--> review
# review --nsubj--> come
# do --aux--> come
# not --neg--> come
# come --ccomp--> be
# phrase --dobj--> come
# like --prep--> come
# good --amod--> movi
# movi --pobj--> like
# ever --advmod--> fck
# fck --amod--> style
# movi --compound--> style
# third --compound--> anim
# anim --compound--> style
# style --dobj--> review
# across --prep--> review
# spiderver --pobj--> across
# somewhat --advmod--> differ
# differ --amod--> style
# anim --compound--> style
# style --dobj--> review
# spiderver --prep--> style
# scene --compound--> anim
# anim --pobj--> spiderver
# spiderver --prep--> style
# almost --advmod--> photorealist
# photorealist --amod--> anim
# anim --pobj--> spiderver
# across --prep--> anim
# spiderver --pobj--> across
# often --advmod--> film
# almost --advmod--> impressionist
# impressionist --amod--> film
# film --compound--> background
# featur --compound--> beauti
# beauti --compound--> background
# detail --compound--> background
# background --pobj--> across
# fourth --advmod--> background
# would --aux--> go
# not --neg--> go
# go --conj--> review
# far --advmod--> say
# say --advcl--> go
# across --prep--> go
# spiderver --prep--> across
# well --advmod--> film
# film --pobj--> across
# spiderver --nsubj--> think
# think --conj--> review
# theyr --nmod--> impress
# equal --amod--> impress
# impress --dobj--> think
# though --advmod--> review
# across --prep--> review
# spiderver --nmod--> auditorium
# perhap --pobj--> spiderver
# excit --amod--> auditorium
# film --compound--> auditorium
# fifth --amod--> peopl
# peopl --compound--> auditorium
# auditorium --pobj--> across
# get --aux--> see
# see --advcl--> review
# anim --compound--> adult
# film --compound--> adult
# adult --compound--> latetwenti
# latetwenti --compound--> enjoy
# thirti --nmod--> enjoy
# earlyfourti --amod--> enjoy
# old --amod--> peopl
# peopl --compound--> enjoy
# enjoy --nsubj--> see
# see --ccomp--> see
# film --compound--> lot
# lot --nsubj--> go
# go --ccomp--> see
# similar --amod--> woman
# peculiar --amod--> experi
# experi --compound--> watch
# watch --compound--> februari
# titan --compound--> theater
# theater --compound--> februari
# februari --compound--> woman
# year --compound--> woman
# peopl --compound--> auditorium
# auditorium --compound--> woman
# woman --dobj--> go
# mostli --compound--> woman
# young --amod--> woman
# woman --compound--> excit
# truli --compound--> excit
# excit --compound--> film
# even --advmod--> cri
# cri --compound--> film
# time --compound--> film
# film --nsubj--> begin
# come --compound--> credit
# end --compound--> credit
# credit --appos--> film
# begin --conj--> review
# roll --compound--> member
# member --compound--> begin
# fair --amod--> sex
# sex --compound--> begin
# begin --compound--> film
# talk --compound--> film
# excitedli --compound--> film
# film --nsubj--> say
# say --ROOT--> say
# jame --compound--> cameron
# cameron --compound--> know
# know --nsubj--> make
# make --ccomp--> say
# film --compound--> woman
# appeal --compound--> man
# man --compound--> woman
# woman --nsubj--> wonder
# wonder --compound--> film
# film --nsubj--> bring
# bring --ccomp--> make
# much --amod--> cash
# cash --compound--> sixth
# sixth --dobj--> bring
# see --dobj--> bring
# across --prep--> see
# spiderver --pobj--> across
# later --advmod--> make
# make --dep--> say
# spend --ccomp--> make
# half --amod--> day
# day --compound--> watch
# watch --nsubj--> spend
# spiderver --prep--> watch
# video --compound--> watch
# watch --compound--> scene
# scene --pobj--> spiderver
# sever --amod--> time
# time --nsubj--> paus
# often --advmod--> paus
# paus --ccomp--> make
# movi --compound--> order
# order --nsubj--> look
# look --ccomp--> paus
# background --compound--> charact
# charact --nsubj--> design
# design --ccomp--> look
# true --amod--> move
# gwen --compound--> staci
# staci --compound--> sometim
# sometim --compound--> move
# move --dobj--> design
# like --prep--> move
# ballet --compound--> dancer
# dancer --compound--> film
# film --pobj--> like
# watch --conj--> look
# across --prep--> watch
# spidervers --compound--> bare
# bare --pobj--> across
# know --ccomp--> say
# anyth --compound--> filmmak
# phil --compound--> lord
# lord --compound--> miller
# christoph --compound--> miller
# miller --compound--> filmmak
# interest --compound--> filmmak
# filmmak --nsubj--> take
# do --aux--> take
# take --ccomp--> know
# look --nmod--> work
# filmographi --amod--> turn
# turn --nsubj--> work
# work --ccomp--> take
# sever --amod--> film
# film --dobj--> work
# like --prep--> work
# quit --compound--> lot
# lot --pobj--> like
# get --aux--> see
# see --advcl--> take
# film --compound--> theater
# theater --dobj--> see
#
#
# Sentence 1000:
# fly instant want express gratitud everyon work masterpiec anim music empha make cri watch well I have see last year I be wait rd part masterpiecespiderman web univer rich dramat inten luxuri wrapper strong moment obviou villain push back devot time interperson conflict protagonist everyth simpl great effect author superbl wind wind expect explo feel think word occur time seem comedi cartoon like should not hope someth seriou script hit confid intellig topic think conver gener want true comic agenda away social realism solv problem multiver cheer fan servic profession approach everyon happi summer begin
#
# Constituency Parse Tree:
# (S
#   fly/NNS
#   instant/VBP
#   want/VBP
#   express/JJ
#   gratitud/NN
#   everyon/NN
#   work/NN
#   masterpiec/NN
#   anim/JJ
#   music/NN
#   empha/NNS
#   make/VBP
#   cri/NN
#   watch/NN
#   well/RB
#   I/PRP
#   have/VBP
#   see/VBN
#   last/JJ
#   year/NN
#   I/PRP
#   be/VB
#   wait/VBN
#   rd/JJ
#   part/NN
#   masterpiecespiderman/NN
#   web/NN
#   univer/NN
#   rich/JJ
#   dramat/NN
#   inten/JJ
#   luxuri/JJ
#   wrapper/NN
#   strong/JJ
#   moment/NN
#   obviou/NN
#   villain/NN
#   push/NN
#   back/RB
#   devot/JJ
#   time/NN
#   interperson/JJ
#   conflict/NN
#   protagonist/NN
#   everyth/NN
#   simpl/NN
#   great/JJ
#   effect/NN
#   author/NN
#   superbl/NN
#   wind/NN
#   wind/NN
#   expect/VBP
#   explo/JJ
#   feel/NN
#   think/VBP
#   word/NN
#   occur/NN
#   time/NN
#   seem/VBP
#   comedi/RB
#   cartoon/VBP
#   like/NNS
#   should/MD
#   not/RB
#   hope/VB
#   someth/NNS
#   seriou/JJ
#   script/NN
#   hit/VBD
#   confid/JJ
#   intellig/JJ
#   topic/NN
#   think/VBP
#   conver/NN
#   gener/NN
#   want/VBP
#   true/JJ
#   comic/JJ
#   agenda/NN
#   away/RB
#   social/JJ
#   realism/NN
#   solv/NN
#   problem/NN
#   multiver/NN
#   cheer/NN
#   fan/NN
#   servic/JJ
#   profession/NN
#   approach/NN
#   everyon/NN
#   happi/NN
#   summer/NN
#   begin/NN)
#
# Dependency Parse:
# fly --ROOT--> fly
# instant --dobj--> fly
# want --dep--> fly
# express --amod--> everyon
# gratitud --compound--> everyon
# everyon --nsubj--> work
# work --dobj--> want
# masterpiec --amod--> empha
# anim --compound--> music
# music --compound--> empha
# empha --dobj--> fly
# make --conj--> fly
# cri --nsubj--> watch
# watch --ccomp--> make
# well --intj--> see
# I --nsubj--> see
# have --aux--> see
# see --advcl--> simpl
# last --amod--> year
# year --npadvmod--> see
# I --nsubjpass--> wait
# be --auxpass--> wait
# wait --ccomp--> see
# rd --dep--> univer
# part --compound--> web
# masterpiecespiderman --compound--> web
# web --nsubj--> univer
# univer --advcl--> wait
# rich --amod--> dramat
# dramat --nsubj--> inten
# inten --ccomp--> see
# luxuri --compound--> wrapper
# wrapper --dobj--> inten
# strong --amod--> moment
# moment --npadvmod--> inten
# obviou --ccomp--> see
# villain --nsubj--> push
# push --ccomp--> obviou
# back --advmod--> push
# devot --compound--> time
# time --compound--> protagonist
# interperson --compound--> conflict
# conflict --compound--> protagonist
# protagonist --dobj--> push
# everyth --nsubj--> simpl
# simpl --ROOT--> simpl
# great --amod--> effect
# effect --compound--> author
# author --compound--> wind
# superbl --compound--> wind
# wind --compound--> wind
# wind --nsubj--> expect
# expect --ccomp--> simpl
# explo --nsubj--> feel
# feel --nsubj--> seem
# think --compound--> word
# word --compound--> time
# occur --compound--> time
# time --nsubj--> seem
# seem --ccomp--> expect
# comedi --amod--> cartoon
# cartoon --oprd--> seem
# like --prep--> seem
# should --aux--> hope
# not --neg--> hope
# hope --advcl--> simpl
# someth --amod--> script
# seriou --compound--> script
# script --nsubj--> hit
# hit --ccomp--> hope
# confid --compound--> intellig
# intellig --compound--> topic
# topic --npadvmod--> simpl
# think --ccomp--> simpl
# conver --compound--> gener
# gener --nsubj--> want
# want --ccomp--> think
# true --amod--> agenda
# comic --amod--> agenda
# agenda --dobj--> want
# away --advmod--> want
# social --amod--> realism
# realism --dobj--> want
# solv --amod--> problem
# problem --appos--> realism
# multiver --advmod--> begin
# cheer --compound--> everyon
# fan --compound--> everyon
# servic --compound--> profession
# profession --compound--> everyon
# approach --compound--> everyon
# everyon --compound--> happi
# happi --compound--> summer
# summer --nsubj--> begin
# begin --ccomp--> want
#
# Parsing completed for all sentences.

# %% [markdown]
# # (3) Named Entity Recognition

# %%
import spacy
import pandas as pd
from collections import Counter

# Loading the spaCy model
nlp = spacy.load("en_core_web_sm")

# Function to perform NER
def perform_ner(text):
    doc = nlp(text)  # Process the text using the spaCy model
    return [(ent.text, ent.label_) for ent in doc.ents]  # Extract entities and their labels

# Loading the cleaned data from CSV file
dataFrame = pd.read_csv('imdb_reviews_cleaned.csv')

# Performing NER on all the cleaned texts extracted from the CSV file
all_entities = []

for index, row in dataFrame.iterrows():
    text = row['Lemmatized']  # Access the lemmatized text
    entities = perform_ner(text)
    all_entities.extend(entities)

    # Printing all entities for each text
    print(f"\nEntities in text {index + 1}:")
    for entity, label in entities:
        print(f"{entity} - {label}")

# Calculating the count of each entity type
entity_counts = Counter(label for _, label in all_entities)

print("\nTotal entity counts:")
for entity_type, count in entity_counts.items():
    print(f"{entity_type}: {count}")

# Creating a list of all unique entities
unique_entities = list(set(all_entities))

print("\nSample of unique entities found (up to 20):")
for entity, label in unique_entities[:20]:
    print(f"{entity} - {label}")

# Saving the results to CSV
results_dataFrame = pd.DataFrame(unique_entities, columns=['Entity', 'Type'])
results_dataFrame.to_csv('named_entities.csv', index=False)
print("\nFull list of named entities saved to 'named_entities.csv'")
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Entities in text 391:
# cool movi long time - ORG
# mile - QUANTITY
#
# Entities in text 392:
# five - CARDINAL
# five - CARDINAL
# cliffhang - ORG
# one - CARDINAL
# realiti accompani undeni truth - PERSON
# believ challeng - ORG
# hurdl emerg - ORG
# vividli display mile - EVENT
# lesson impart - PERSON
# mile emerg - PERSON
# relat - PERSON
# battl strike - PERSON
# coupl apprehen - PERSON
# urg safeguard - PERSON
# peter demis experi parallel - PERSON
# world instanc - ORG
# age mile - DATE
# effortlessi distinctli - PERSON
# realiti spiderperson life integr intric detail fluid - PERSON
# narr - ORG
# genr - GPE
# reson profoundli - PERSON
#
# Entities in text 393:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# movi charact thereinc wait - ORG
# next one - DATE
#
# Entities in text 394:
# thrill - GPE
# precis creativ - PERSON
# innov - PERSON
#
# Entities in text 395:
#
# Entities in text 396:
# confus - ORG
# everi movi - PERSON
# two - CARDINAL
#
# Entities in text 397:
# first - ORDINAL
# everi differ - PERSON
# indian - NORP
# chao - PERSON
# indian - NORP
# first - ORDINAL
# half - CARDINAL
#
# Entities in text 398:
# first - ORDINAL
# issu - ORG
# reveng - PERSON
# miguel unfortun - PERSON
# issu - ORG
#
# Entities in text 399:
# unfortun kid - PERSON
# festth - ORG
# onth - DATE
# mani polit - PERSON
#
# Entities in text 400:
# first - ORDINAL
# fulli - PERSON
# experi sinc year - DATE
# today - DATE
# relat teen - PERSON
# cri mile - ORG
# cri - NORP
#
# Entities in text 401:
# tonight - TIME
# everi - PERSON
#
# Entities in text 402:
# movi visual incre cool gorgeou - ORG
# compar precursor movi - ORG
#
# Entities in text 403:
# fellow spiderperson - PERSON
# miguel ohara jessica - PERSON
# ben reilli - PERSON
# peter parker - PERSON
# togeth - CARDINAL
# dedic - PERSON
# delight fan agesth film - FAC
# relat - PERSON
# thrill - GPE
#
# Entities in text 404:
# everyth youv - PERSON
# sinc hour - TIME
# cliffhang escal nemesi - ORG
#
# Entities in text 405:
# first - ORDINAL
# british - NORP
# eight year old - DATE
# netflix - GPE
# slightli - GPE
# weekend - DATE
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 406:
# kemp - ORG
# justin k thompson featur directori - PERSON
# narr - PERSON
# first - ORDINAL
# half - CARDINAL
# everi frame - PERSON
# nitpick - PERSON
# narr - PERSON
# first - ORDINAL
# everi - PRODUCT
# one - CARDINAL
# genr marvel - ORG
# seri - NORP
#
# Entities in text 407:
# everyon - CARDINAL
# momenttyp - PERSON
# two - CARDINAL
# two hour - TIME
# half - CARDINAL
# two two hour - TIME
#
# Entities in text 408:
# marvelreviewa lifelong spiderman - PERSON
# leav diehard fan - FAC
# journey relat - PERSON
# inspiringon - PERSON
# spiderperson - ORG
# quirk tabl make - PERSON
# hilari - NORP
# parker gwen staci spiderman - ORG
# peni parker portray brilliantli - ORG
# experi - NORP
# storytel superhero - PRODUCT
# mytho - ORG
# lover - ORG
#
# Entities in text 409:
# first - ORDINAL
# two - CARDINAL
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 410:
# first - ORDINAL
# two hour - TIME
# third - ORDINAL
# one - CARDINAL
# two - CARDINAL
# second - ORDINAL
# half - CARDINAL
# comingofag - ORG
# one - CARDINAL
# everyon el - PERSON
#
# Entities in text 411:
# mile moraless - PERSON
# everi fascin frame - PERSON
# spectacl - ORG
# societi amus - PERSON
# first - ORDINAL
# intertwin multipl - PERSON
# spidey - PERSON
# everi storylin - PERSON
# everi superhero - PERSON
#
# Entities in text 412:
# everi frame - PERSON
# third movi second season - DATE
# creativ pleasur - ORG
# first - ORDINAL
#
# Entities in text 413:
# first - ORDINAL
# shameik - NORP
# narr deftli balanc - ORG
# shameik - PRODUCT
# shine mile - QUANTITY
# camaraderi - GPE
# inspiringon - GPE
# aficionado - GPE
# narr - PRODUCT
# reson multipl - PERSON
# second - ORDINAL
# deliv compel - ORG
#
# Entities in text 414:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 415:
# believ movi creativ manipul tradit - ORG
# mei believ movi creativ manipul tradit - ORG
# first - ORDINAL
# mile - PERSON
# first - ORDINAL
# half - CARDINAL
# miguel ohara - PERSON
# miguel everi - PERSON
# miguel control - PERSON
# mile miguel amazingli - PERSON
# first - ORDINAL
# miguel argument - PERSON
# miguel one - PERSON
# issu - ORG
# around mile - QUANTITY
# undeni - NORP
# chang - PERSON
# possibleth animationth - ORG
# manag merg - PERSON
#
# Entities in text 416:
# first - ORDINAL
# deep confu - PERSON
# charisma everybodyi - ORG
# second - ORDINAL
# english - NORP
# first - ORDINAL
#
# Entities in text 417:
# one - CARDINAL
# rick morti - PERSON
# absolut everyon abl - PERSON
# two - CARDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 418:
# first - ORDINAL
# liter hundr - PERSON
# mile - TIME
# spoton creativ memor action - PERSON
# mostli uniqu - PERSON
# everyth - ORG
# peter parker - PERSON
# dozen - CARDINAL
# representationethn - ORG
# openli tran - PERSON
# second - ORDINAL
# one - CARDINAL
#
# Entities in text 419:
# year - DATE
# first - ORDINAL
# two - CARDINAL
# one - CARDINAL
# half - CARDINAL
# second - ORDINAL
# two - CARDINAL
#
# Entities in text 420:
# one - CARDINAL
# first - ORDINAL
# two - CARDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 421:
# minut intro - PERSON
# one - CARDINAL
# third - ORDINAL
#
# Entities in text 422:
# first - ORDINAL
# two magnific - TIME
# appar studio believ - PERSON
# believ magic - PERSON
#
# Entities in text 423:
# second - ORDINAL
# first - ORDINAL
# everi singl - PERSON
# one - CARDINAL
#
# Entities in text 424:
# reveng - PERSON
#
# Entities in text 425:
# everi singl - PERSON
# one - CARDINAL
# quippi coupl moment - PRODUCT
# snappi - PERSON
# seri - NORP
#
# Entities in text 426:
# univer movi - ORG
# everi univer - PERSON
# one - CARDINAL
#
# Entities in text 427:
# first - ORDINAL
# unfortun mani - PERSON
# first - ORDINAL
# storylin movi - ORG
# first - ORDINAL
#
# Entities in text 428:
# henri luna lauren - PERSON
# two - CARDINAL
# characterjak johnson - PERSON
# peter - PERSON
# specif jason - PERSON
# issa rae jessica draw - PERSON
# daniel kaluuya - PERSON
# everi charact - PERSON
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 429:
# narr - PERSON
# one - CARDINAL
# everi spiderman happen - PERSON
# one - CARDINAL
# liter talk - PERSON
# everyon - CARDINAL
#
# Entities in text 430:
# halfway arriv point mile - ORG
# miguel tri - PERSON
# third - ORDINAL
#
# Entities in text 431:
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 432:
# one - CARDINAL
# one - CARDINAL
# gorgeou - NORP
# everyth hereth - PERSON
# third - ORDINAL
# one - CARDINAL
# narr - PERSON
#
# Entities in text 433:
# one - CARDINAL
# cliffhang - ORG
# first - ORDINAL
# movi movi - ORG
# one - CARDINAL
#
# Entities in text 434:
# wildli creativ emot - ORG
# first - ORDINAL
#
# Entities in text 435:
# first - ORDINAL
# extrem - PERSON
# realiti introduc intrigu spiderman varieti dive - ORG
# first - ORDINAL
# relat - PERSON
# two hour - TIME
# two hour - TIME
#
# Entities in text 436:
# one - CARDINAL
# shameik - PRODUCT
# everi voic - PERSON
# everi moment - PRODUCT
# characterwis mile - QUANTITY
# journey potenti good spiderman - PERSON
# first - ORDINAL
# half - CARDINAL
# first - ORDINAL
# second - ORDINAL
#
# Entities in text 437:
# year - DATE
# superhero movi - ORG
# first - ORDINAL
# kudo marvelsoni creat - PERSON
#
# Entities in text 438:
# one - CARDINAL
# origin mile - QUANTITY
# one mile - QUANTITY
#
# Entities in text 439:
# first - ORDINAL
# expertli - PERSON
# first - ORDINAL
#
# Entities in text 440:
# messi movi - PERSON
# materi provid - PERSON
#
# Entities in text 441:
# one - CARDINAL
#
# Entities in text 442:
# spectacl fill depth charact - ORG
# first - ORDINAL
# large talein - PERSON
# first - ORDINAL
# two - CARDINAL
# second - ORDINAL
# first - ORDINAL
# one - CARDINAL
# expans - NORP
# mile journey - PERSON
#
# Entities in text 443:
# half - CARDINAL
# one - CARDINAL
# mustwatchif - PERSON
# next year - DATE
# half - CARDINAL
#
# Entities in text 444:
# directli comic act - ORG
# first - ORDINAL
#
# Entities in text 445:
# zeitgeist express sinc - ORG
# experi - NORP
# john faith - PERSON
# al gener - PERSON
# lantern corp clearli inspir spiderperson corp readi - ORG
#
# Entities in text 446:
# almost million - CARDINAL
# first - ORDINAL
# year - DATE
# mile moralesspiderman - PERSON
# adventur - GPE
# seri - NORP
# phil lord - PERSON
# christoph miller deliv - PERSON
# importantli - GPE
# first - ORDINAL
# issu - ORG
# two half hour - TIME
# narr - ORG
# one - CARDINAL
# adventur - GPE
# new york - GPE
# mumbai - GPE
# first - ORDINAL
# miguel ohara jason schwartzman - PERSON
# daniel kaluuya - PERSON
# hobart brown - PERSON
# first - ORDINAL
# next year - DATE
# jordan - GPE
#
# Entities in text 447:
# madoka magica - ORG
# extrem - PERSON
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 448:
# first - ORDINAL
# spectacl - ORG
# everi frame - PERSON
# spectacl servic - ORG
#
# Entities in text 449:
# superhero movi charact - ORG
# relat spiderperson - PERSON
# johnson peter - PERSON
# thrill - GPE
#
# Entities in text 450:
# storylin - GPE
# half - CARDINAL
# biti realli - PERSON
# first - ORDINAL
# averag movi mostli - ORG
# averag moviesmayb - PERSON
#
# Entities in text 451:
# one - CARDINAL
# spiderperson - ORG
# worldbuild - PERSON
# dramat moment - PERSON
# chang thingther mani - PERSON
# prais movi big one - ORG
# movi big fan - ORG
# qualiti movi - ORG
# believ break - ORG
# next one - DATE
# mildli - GPE
# experi - NORP
# two - CARDINAL
# divid two watch - PERSON
# mile - PERSON
#
# Entities in text 452:
# showcas matur - PERSON
# arachnid - PERSON
# funni comedi - ORG
# treasur hunt cinephil comic book - PERSON
# first - ORDINAL
# kaleidoscop comic - PERSON
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 453:
# everi - PRODUCT
# somethingfilmat begin dive - ORG
# first - ORDINAL
# everi - PERSON
# chri miller - PERSON
# month - DATE
# movi mile - ORG
# one day - DATE
# year - DATE
#
# Entities in text 454:
# two - CARDINAL
# half - CARDINAL
# week - DATE
# everi singl - PERSON
# first - ORDINAL
#
# Entities in text 455:
# surpris - NORP
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# chri miller - PERSON
# dave callaham - PERSON
# third - ORDINAL
# first - ORDINAL
# first - ORDINAL
# zero - CARDINAL
# favourit movi far truli - ORG
# everi - PERSON
#
# Entities in text 456:
# surpris arriv cinema - WORK_OF_ART
# first - ORDINAL
# footstepsmi issu one - PERSON
# everi - PERSON
# storylin movi includ - ORG
#
# Entities in text 457:
# first - ORDINAL
#
# Entities in text 458:
# first - ORDINAL
# extrem meta realiti - PERSON
# first - ORDINAL
# miguel ohara convey burden - PERSON
# british - NORP
# year sinc - DATE
# justin k thompson - PERSON
# everi - PERSON
# daniel pemberton - PERSON
# two - CARDINAL
# realli outdon - ORG
# one - CARDINAL
#
# Entities in text 459:
# half - CARDINAL
# min - ORG
#
# Entities in text 460:
# funni unfortun - ORG
# miguel - PERSON
# miguel - PERSON
# third - ORDINAL
# unfortun - PERSON
#
# Entities in text 461:
# today - DATE
# relat - PERSON
# first - ORDINAL
# ten - CARDINAL
# minut movi - ORG
# spectacl thrill - GPE
# two - CARDINAL
# natur - PERSON
# first - ORDINAL
# half - CARDINAL
# two - CARDINAL
#
# Entities in text 462:
# gener - ORG
# spectacl - ORG
# two - CARDINAL
# week - DATE
# month - DATE
# relat - PERSON
#
# Entities in text 463:
# one - CARDINAL
# one - CARDINAL
# hilari - NORP
# root mile - ORG
# one - CARDINAL
# one - CARDINAL
# summer - DATE
#
# Entities in text 464:
# mishandl spidey - PERSON
# showcas - LANGUAGE
# everi singl - PERSON
#
# Entities in text 465:
# everyth movi - ORG
# peter cool - PERSON
# third - ORDINAL
#
# Entities in text 466:
# first - ORDINAL
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 467:
# year movi - DATE
# primari - ORG
# quest - PRODUCT
# favorit spiderman movi - ORG
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 468:
# cliffhang movi sinc - ORG
# warmil - PERSON
# truli - GPE
# everi spiderman - PERSON
# miguel hara - PERSON
#
# Entities in text 469:
# mile sorri - PERSON
# ten - CARDINAL
#
# Entities in text 470:
# movi convolut - ORG
# minut movi - ORG
# beingdun dun - PERSON
# one - CARDINAL
# american - NORP
# ton english - PERSON
#
# Entities in text 471:
# first - ORDINAL
# third - ORDINAL
#
# Entities in text 472:
# modif - PERSON
# philosoph mediat - ORG
# free chao natur - PERSON
# one - CARDINAL
# realiti - GPE
# third - ORDINAL
#
# Entities in text 473:
# second - ORDINAL
# fuell - PERSON
# beauti - CARDINAL
# one - CARDINAL
# subtitl sometim - PERSON
# chao walk - PERSON
#
# Entities in text 474:
# movi knock - ORG
# first - ORDINAL
# second - ORDINAL
# someth - ORDINAL
# greati - PERSON
# first - ORDINAL
# chang charact - PERSON
#
# Entities in text 475:
# innov - PERSON
# third - ORDINAL
# third - ORDINAL
#
# Entities in text 476:
# first - ORDINAL
# narr - PERSON
# delight complement - PERSON
#
# Entities in text 477:
# one - CARDINAL
# third - ORDINAL
# one - CARDINAL
# year - DATE
# issu - PERSON
# anoth year - DATE
#
# Entities in text 478:
# third - ORDINAL
# holland - GPE
# opinionth - ORDINAL
# seri - NORP
#
# Entities in text 479:
# one - CARDINAL
# stan lee - PERSON
# newthen - GPE
# seri - NORP
# first - ORDINAL
# three - CARDINAL
# nichola hammond - ORG
# dragon challeng - PERSON
# reinforc - PERSON
# afternoon - TIME
# first - ORDINAL
# john wesley - PERSON
# seri - NORP
# john wesley - PERSON
# bruce campbel - PERSON
# two - CARDINAL
# sam raimi direct - PERSON
# spiderver mile - QUANTITY
# miguel ohara - PERSON
# peter parker - PERSON
# stan lee - PERSON
#
# Entities in text 480:
# amazingse mile - PERSON
# third - ORDINAL
# next year - DATE
#
# Entities in text 481:
# cartoon spiderman movi - ORG
# villian gorgeou cartoon - ORG
# one - CARDINAL
#
# Entities in text 482:
# indian - NORP
#
# Entities in text 483:
# one - CARDINAL
# mile gwen - PERSON
# miguel - PERSON
# one - CARDINAL
# hilari - NORP
# peter - PERSON
# funni charm - ORG
#
# Entities in text 484:
# first - ORDINAL
# one - CARDINAL
# seri - NORP
# first - ORDINAL
# second - ORDINAL
# peter parker mile - PERSON
# first - ORDINAL
# challeng - PERSON
# third - ORDINAL
#
# Entities in text 485:
# outrag gorgeou - PERSON
# qualiti - ORG
# one - CARDINAL
# qualiti - PERSON
#
# Entities in text 486:
# singl - PERSON
# first - ORDINAL
# genr spiderver honestli - PRODUCT
# slowmo gwen - PERSON
# one - CARDINAL
# second - ORDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 487:
# horribl movi - PERSON
# metro - FAC
# one - CARDINAL
#
# Entities in text 488:
# confus - ORG
# two - CARDINAL
# one - CARDINAL
#
# Entities in text 489:
#
# Entities in text 490:
# zero - CARDINAL
# one - CARDINAL
# issu - ORG
#
# Entities in text 491:
# year - DATE
#
# Entities in text 492:
# everi second - PERSON
# beauti - CARDINAL
# breathtak luxuri - PERSON
# deliv bounti - ORG
#
# Entities in text 493:
# mile - PERSON
# figur captan - PERSON
#
# Entities in text 494:
#
# Entities in text 495:
#
# Entities in text 496:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# narr - PERSON
# everi scene chang - PERSON
# first - ORDINAL
# awar - PERSON
# two hour - TIME
# narr - PERSON
#
# Entities in text 497:
# meta narr - PERSON
# boundari - ORG
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 498:
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# dang inevit - PERSON
# nitpicki - PRODUCT
# spanish - NORP
# spanish - NORP
# indian - NORP
# crazi movi buthonestli - ORG
#
# Entities in text 499:
# frenesi cheesi - PERSON
# first - ORDINAL
# everi minut lifeanddeath crisisi - PERSON
# two - CARDINAL
# activ verifi plu villain - PERSON
#
# Entities in text 500:
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# casecameo place - PERSON
# one - CARDINAL
# surpris - NORP
# quot movi - ORG
# next year - DATE
#
# Entities in text 501:
# first hour wast hour first hour - TIME
# blabber second hour - TIME
# two - CARDINAL
# first hour - TIME
# mile constantli - PERSON
# late someth - TIME
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# second - ORDINAL
# half - CARDINAL
#
# Entities in text 502:
#
# Entities in text 503:
# first - ORDINAL
# one - CARDINAL
# second - ORDINAL
# first - ORDINAL
# one - CARDINAL
# everi - PERSON
# terrif - PERSON
# noooooo - GPE
# one - CARDINAL
#
# Entities in text 504:
# miguel ohara - PERSON
# miguel group - ORG
# mysteri planth - PERSON
# chemistri isaac - PERSON
# miguel act mentor - ORG
# mile schwartzman - PERSON
# spiderperson - ORG
# johnson peter - PERSON
# parker brian tyre - ORG
# henri jefferson - ORG
# luna lauren - PERSON
# issa rae jessica - PERSON
# prabhakar spiderman india daniel kaluuya - ORG
# hobart hobi brown - PERSON
# miguel ohara spiderman mani - PERSON
# challeng motiv film - PERSON
#
# Entities in text 505:
# mile - PERSON
# one - CARDINAL
# first - ORDINAL
# robberi - NORP
# miguel - PERSON
# almost hour - TIME
# miguel differ - PERSON
# jessica draw peter - PERSON
# miguel - PERSON
# peter parker - PERSON
# dr strang send - PERSON
# issu - ORG
#
# Entities in text 506:
# second - ORDINAL
# third - ORDINAL
#
# Entities in text 507:
# first - ORDINAL
# everi spiderperson univer person - PERSON
# one - CARDINAL
# jason schwartzman - PERSON
# miguel hara - PERSON
# second - ORDINAL
#
# Entities in text 508:
# two - CARDINAL
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
# one - CARDINAL
# gener - ORG
# first - ORDINAL
# seri - ORG
# third - ORDINAL
# second - ORDINAL
# two - CARDINAL
# three - CARDINAL
#
# Entities in text 509:
# liter stori movi - ORG
# one - CARDINAL
# issu movi - ORG
# narr - PERSON
# one - CARDINAL
#
# Entities in text 510:
# issu - ORG
# everi time - PERSON
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 511:
# first - ORDINAL
# earth howev - LOC
# nemesi take - PERSON
# week - DATE
# stacey spiderwoman - PERSON
# togeth - CARDINAL
# realiti - PERSON
# everi univer - PERSON
#
# Entities in text 512:
# spectacl behold - ORG
# everi frame - PERSON
# first - ORDINAL
# second - ORDINAL
# everi scene movi unpredict - PERSON
#
# Entities in text 513:
# highqual - DATE
# beauti eyepop - PERSON
# almost two half hour - TIME
# adventur - GPE
# brooklyn - GPE
#
# Entities in text 514:
# everi depart - PERSON
# one - CARDINAL
# everi sen - PERSON
# one - CARDINAL
#
# Entities in text 515:
# unfortun - PERSON
# issu - ORG
# narr - ORG
# first - ORDINAL
# narr - ORG
# flashi visual serv highlight - PERSON
# experi - NORP
#
# Entities in text 516:
# one - CARDINAL
# first - ORDINAL
# fulli - PERSON
# provid sen - PERSON
# first - ORDINAL
#
# Entities in text 517:
# two - CARDINAL
# one - CARDINAL
# seri - NORP
# itin gener - PERSON
#
# Entities in text 518:
# awesom anim - PERSON
# one - CARDINAL
# two - CARDINAL
# relat - PERSON
# mayb - GPE
#
# Entities in text 519:
# michael - PERSON
# stan lee - PERSON
# mile - QUANTITY
#
# Entities in text 520:
# ben riley - PERSON
# pavitr prabhakar - PERSON
# andrew garfield - PERSON
# maguir - GPE
# one - CARDINAL
# one - CARDINAL
# everi comic book - PERSON
#
# Entities in text 521:
# synopsi - PERSON
# experi everi - PERSON
# first - ORDINAL
# first - ORDINAL
# howev film mile - QUANTITY
# third - ORDINAL
# first - ORDINAL
# second - ORDINAL
# shameik - PERSON
# happi characterspeak - FAC
# one - CARDINAL
# daniel pemberton - PERSON
# whenev convers - ORG
# ten - CARDINAL
# june - DATE
#
# Entities in text 522:
# visual movi allth - ORG
# funni - ORG
#
# Entities in text 523:
# first - ORDINAL
# one - CARDINAL
# five hour - TIME
#
# Entities in text 524:
# list movi - ORG
# year - DATE
# shortvisu stun - PERSON
# english - NORP
# alonewrit awesom easi - PERSON
#
# Entities in text 525:
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 526:
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# half - CARDINAL
# mani line - PERSON
# first - ORDINAL
# one - CARDINAL
# touch mile - QUANTITY
# graffiti mile - PERSON
# indian - NORP
# peter b parker mani - PERSON
# first - ORDINAL
# mile leap - PERSON
# second - ORDINAL
# first half - DATE
# first - ORDINAL
# thrillermysteri - PRODUCT
#
# Entities in text 527:
# first - ORDINAL
# half - CARDINAL
# tragedi univer - PERSON
# light mile - QUANTITY
#
# Entities in text 528:
# first - ORDINAL
# first - ORDINAL
# half - CARDINAL
# first - ORDINAL
#
# Entities in text 529:
#
# Entities in text 530:
# one - CARDINAL
# mile prowler - PERSON
#
# Entities in text 531:
# awesom sauc - PERSON
#
# Entities in text 532:
# hour - TIME
# year old - DATE
#
# Entities in text 533:
# caus marvel fan - ORG
# meet aveng - PERSON
#
# Entities in text 534:
# ad past week - DATE
# quarter - CARDINAL
# alphyeditz - ORG
#
# Entities in text 535:
# miguel ohara - PERSON
#
# Entities in text 536:
# two - CARDINAL
# two - CARDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 537:
# shameik - NORP
# johnson issa rae daniel kaluuya - PERSON
#
# Entities in text 538:
# past year - DATE
# past year - DATE
# peter parker - PERSON
# screwup loser - PERSON
# peter parker constantli - PERSON
# dirti soni - PERSON
# peter parker - PERSON
# loser peter - PERSON
# cool appar - PERSON
# end month - DATE
# peter parker - PERSON
# effemin comic relief - PERSON
# everi singl - PERSON
# background constantli - PERSON
# peter parker - PERSON
# rick morti - PERSON
# rick mile - PERSON
# everi spiderman - PERSON
# everi univer - PERSON
# one - CARDINAL
# one - CARDINAL
# peter parker - PERSON
# child mile - LAW
# cool endang - ORG
# everi spiderman - PERSON
# mile - PERSON
# one - CARDINAL
# issu - ORG
# mile - QUANTITY
# vanguard disney - PRODUCT
#
# Entities in text 539:
# first - ORDINAL
#
# Entities in text 540:
# one - CARDINAL
# adventur - GPE
# substanc watch constantli - PERSON
# feel urg - PERSON
# admir beauti creativ studi detail know - PERSON
# everi scene - PERSON
# meaninga result - ORG
# experi - NORP
#
# Entities in text 541:
#
# Entities in text 542:
# believ superhero - ORG
# first - ORDINAL
# jaw floor unbeliev - PERSON
#
# Entities in text 543:
# justifi - ORG
# everi frame - PERSON
#
# Entities in text 544:
# prepar - PERSON
# storytel narr - PRODUCT
# uniqu struggl - PERSON
# expertli interwoven film emot - ORG
# thrill - DATE
# experi - NORP
# one - CARDINAL
# relat superhero - PERSON
#
# Entities in text 545:
# realiz cartoon bar expen - ORG
# everi moment - PRODUCT
# narr - PERSON
#
# Entities in text 546:
# littl - PERSON
# alli - PERSON
# first - ORDINAL
# beauti jawdroppingi realli - PERSON
# heri - PERSON
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 547:
# honestli blow - PERSON
# extrem - PERSON
# everi sen - PERSON
#
# Entities in text 548:
# ben - PERSON
#
# Entities in text 549:
# one - CARDINAL
# everi singl - PERSON
# everi singl - PERSON
# everi - ORG
# movi flawless movi - ORG
# believ - GPE
#
# Entities in text 550:
# one - CARDINAL
# jake johnson - PERSON
# issac - ORG
# one year - DATE
# alex nolan crave - PERSON
# movi lot sinc - ORG
#
# Entities in text 551:
# everyth epicsaus emot - ORG
# adrenalin beauti - PERSON
# everi minut liter awe newli - PERSON
# movi metro - ORG
# everi spiderman - PERSON
# sinc cliffhang massiv - PERSON
#
# Entities in text 552:
#
# Entities in text 553:
# first - ORDINAL
# miguel ohara - PERSON
# next year - DATE
#
# Entities in text 554:
# captiv intro - PERSON
# one - CARDINAL
# realiti - PERSON
# second - ORDINAL
#
# Entities in text 555:
# unfortun - PERSON
# role spidermani - PERSON
# one - CARDINAL
# first - ORDINAL
# past year - DATE
# first - ORDINAL
#
# Entities in text 556:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# ps one - ORG
# cleari movi opinion probali - ORG
#
# Entities in text 557:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# ten - CARDINAL
#
# Entities in text 558:
# hour - TIME
#
# Entities in text 559:
# someth pixar - LAW
#
# Entities in text 560:
# donald glover prowler - PERSON
#
# Entities in text 561:
# one - CARDINAL
#
# Entities in text 562:
# one - CARDINAL
#
# Entities in text 563:
#
# Entities in text 564:
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 565:
# half - CARDINAL
# worthwhil receiv - PERSON
# unfortun - PERSON
# runtimei - ORG
# consistentlywhil movi mani - ORG
# everyon - CARDINAL
#
# Entities in text 566:
# third - ORDINAL
# everi frame movi - ORG
# one - CARDINAL
# everi time - PERSON
# surpris - NORP
# believ everi - PERSON
# first - ORDINAL
#
# Entities in text 567:
# stall midway - ORG
# abus - ORG
#
# Entities in text 568:
# two hour - TIME
# half - CARDINAL
# hilari - NORP
#
# Entities in text 569:
# necceri - PERSON
# first - ORDINAL
# everi - PERSON
# interstel reles movi - ORG
# everi wayfunnyunexpctedli - PERSON
# bounsno post - ORG
#
# Entities in text 570:
# scari - ORG
# first - ORDINAL
#
# Entities in text 571:
# first - ORDINAL
# one - CARDINAL
# hobi brown - ORG
# third - ORDINAL
# third - ORDINAL
#
# Entities in text 572:
# stun beauti movi - PERSON
# first - ORDINAL
# cliffhang movi part - ORG
#
# Entities in text 573:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# realiti collap microcosm gwen small complet arc - ORG
# replac - ORG
# miguel - PERSON
# thiscurr mile - QUANTITY
# dichotomi miguel - PERSON
# cri - NORP
# mayday - DATE
# hour - TIME
# issu - ORG
#
# Entities in text 574:
# first - ORDINAL
# second - ORDINAL
# plu - ORG
# two - CARDINAL
# first - ORDINAL
# lee - PERSON
# second - ORDINAL
#
# Entities in text 575:
# awar howev base - PERSON
# allen walli west - PERSON
# metahuman - PERSON
# relat - PERSON
#
# Entities in text 576:
# one - CARDINAL
# america remov - PERSON
# first - ORDINAL
# half - CARDINAL
#
# Entities in text 577:
# beauti heartfelt truli - PERSON
# final culmin buildup magnific climax - ORG
# year later - DATE
# narr arc - ORG
# heartfelt narr - PERSON
# half - CARDINAL
# next year - DATE
# one - CARDINAL
# movieseri - NORP
# four hour - TIME
#
# Entities in text 578:
# everi frame - PERSON
# writtenth - LOC
# first - ORDINAL
# half - CARDINAL
#
# Entities in text 579:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# first - ORDINAL
# favourit superhero - ORG
#
# Entities in text 580:
# dime dozen - CARDINAL
# one - CARDINAL
# two - CARDINAL
# oscar isaac mile - PERSON
#
# Entities in text 581:
# extrem - PERSON
# first - ORDINAL
# everi singl - PERSON
# first - ORDINAL
#
# Entities in text 582:
# yesterday - DATE
# experi - NORP
#
# Entities in text 583:
# challeng - PERSON
# boundari - ORG
# reson journey - PERSON
# first - ORDINAL
# narr - PERSON
# believ charact - ORG
# juggl multipl - PERSON
# explor howev - PERSON
# narr - PERSON
# movi social medium - ORG
# first - ORDINAL
# narr - PERSON
# issu - PERSON
#
# Entities in text 584:
# interwoven - CARDINAL
# anoth hour - TIME
# style booti - PERSON
# absolut jaw drop - PERSON
#
# Entities in text 585:
# one - CARDINAL
# everi spiderman - PERSON
# first - ORDINAL
# one - CARDINAL
# today - DATE
# everi ounc - PERSON
# one - CARDINAL
#
# Entities in text 586:
# backstoryoth movi end cliff - ORG
# second - ORDINAL
# one - CARDINAL
#
# Entities in text 587:
# post aveng - PERSON
# next year - DATE
# metaphys crazi - PERSON
# primari - ORG
#
# Entities in text 588:
# june - DATE
# storylin focu - PERSON
# one - CARDINAL
# existenceth cliffhang - PERSON
# one - CARDINAL
#
# Entities in text 589:
# admir spiderman - PERSON
# infus - NORP
# ownth - ORDINAL
# first movi - ORG
# seri - NORP
#
# Entities in text 590:
# god rush movi isi - ORG
# summer - DATE
# seri - NORP
#
# Entities in text 591:
# firstli movi great - ORG
# three - CARDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# issu - ORG
# issu - ORG
# issu - ORG
#
# Entities in text 592:
# insan creativ - PERSON
# one - CARDINAL
# hilari - NORP
# laughingid - PERSON
#
# Entities in text 593:
# tobi maguir film show - PERSON
# chang - PERSON
# two - CARDINAL
# first - ORDINAL
# quibbl masterpiec good superhero - PERSON
#
# Entities in text 594:
# first - ORDINAL
# daniel pemberton - PERSON
# second - ORDINAL
# challeng - ORG
# andrew tobey - PERSON
# cameo usag - PERSON
# first - ORDINAL
# recent year - DATE
# narr convey - ORG
# challeng - PERSON
# third - ORDINAL
# recent year - DATE
# superhero - ORG
# chase mile - ORG
# slightli - PERSON
# showcas - GPE
# recent year - DATE
# mile - QUANTITY
# seri - NORP
# two - CARDINAL
# two - CARDINAL
#
# Entities in text 595:
# next year - DATE
# aka mile - PERSON
#
# Entities in text 596:
# first - ORDINAL
# two - CARDINAL
# adolesc - ORG
# mommi issu - PERSON
# first - ORDINAL
# one - CARDINAL
# quit loweveri - PERSON
# appar everyth - PERSON
#
# Entities in text 597:
# one - CARDINAL
#
# Entities in text 598:
# everi spiderman film - PERSON
# india - GPE
# second - ORDINAL
# chang colour - PERSON
# chase - ORG
# mile emo - PERSON
# hobi brown realli - PERSON
# half - CARDINAL
#
# Entities in text 599:
# appar audienc - ORG
# overlong - GPE
# flashi mess movi - ORG
# everi - PRODUCT
# zero - CARDINAL
# everi one - PERSON
# hour - TIME
# movi notabl - ORG
# year - DATE
#
# Entities in text 600:
# everi shot stun - PERSON
# jumpi dark - LOC
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 601:
# prais visual - PERSON
# mosaic - PRODUCT
# one - CARDINAL
# narr - PERSON
# relat - PERSON
# clear day - DATE
# realli valuabl tool - PERSON
# believ superhero - ORG
# jason schwartzmann - PERSON
# isaac miguel - PERSON
# half hour - TIME
# one - CARDINAL
# half - CARDINAL
# movi movi - ORG
# american - NORP
# pixar copi - PERSON
#
# Entities in text 602:
# eric grade - PERSON
# peter parker - PERSON
# peter parker - PERSON
# first - ORDINAL
# shameik - NORP
# mile - LAW
# brian tyre - PERSON
# henri jeff - PERSON
# notabl - PERSON
# miguel ohara issa rae jess - PERSON
# first - ORDINAL
# first - ORDINAL
# year - DATE
# frontrunn - PERSON
# million box - MONEY
# million - CARDINAL
# one - CARDINAL
# littl mile - ORG
# miguel ohara - PERSON
# shun societi - PERSON
# rel safeti fairli massiv - PERSON
# third - ORDINAL
# mile spider - PERSON
# societi includ - PERSON
# miguel - PERSON
# realiti - PERSON
# peter put fabric realiti - PERSON
# danger besid - PERSON
# two half hour - TIME
# american - NORP
# wondrou spiderrif - PERSON
#
# Entities in text 603:
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# repetit show - PERSON
# first - ORDINAL
#
# Entities in text 604:
# first - ORDINAL
# everyon - CARDINAL
# first - ORDINAL
# one - CARDINAL
# mayb - GPE
# next mile - QUANTITY
#
# Entities in text 605:
# spider societi - PERSON
# first - ORDINAL
# overviewa - ORG
# first - ORDINAL
# societi - PERSON
# battl villian - PERSON
# chang hollyweird - PERSON
# elsegenresuperhero fantasi - PERSON
#
# Entities in text 606:
# honestli think - ORG
# someth - ORDINAL
# somehtin admir - PERSON
# joker instanc - ORG
#
# Entities in text 607:
# truli incre - ORG
# one - CARDINAL
# believ - GPE
# howev gwen - PERSON
# everi second - PERSON
# miller - ORG
# miguel ohara - PERSON
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 608:
# first - ORDINAL
# dri - ORG
# overst - ORDINAL
# remov mayb movi - PERSON
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 609:
# india - GPE
#
# Entities in text 610:
# second - ORDINAL
# half hour - TIME
# first - ORDINAL
#
# Entities in text 611:
# thrill - GPE
# first - ORDINAL
# half - CARDINAL
#
# Entities in text 612:
# first - ORDINAL
# one - CARDINAL
# confus - ORG
# everi - PERSON
# experi - NORP
# one - CARDINAL
#
# Entities in text 613:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 614:
# movi predecessor - ORG
# everyth movieth flaw - PERSON
# mile latin - PERSON
# spanish - NORP
# gener - PERSON
#
# Entities in text 615:
#
# Entities in text 616:
# first - ORDINAL
# first - ORDINAL
# perfectli - ORG
# inspir - ORG
# hundr charact cinematographi visual - ORG
# mesmer howev - PERSON
# miguel spiderman mile - QUANTITY
# luke - PERSON
# vader potenti - PERSON
# third - ORDINAL
# first - ORDINAL
# second - ORDINAL
# mile - PERSON
# third - ORDINAL
#
# Entities in text 617:
# spiderman experi - PERSON
# second - ORDINAL
#
# Entities in text 618:
# half - CARDINAL
# second - ORDINAL
# year second - DATE
# bill dislik - PERSON
# one - CARDINAL
# month - DATE
#
# Entities in text 619:
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# first mile - QUANTITY
# dynam movi - ORG
# indian - NORP
# completli flat - ORG
# mostli - PERSON
# fanfar unbeliev spiderman reveal - ORG
# one - CARDINAL
# two - CARDINAL
#
# Entities in text 620:
# daniel pemberton - PERSON
# first - ORDINAL
# daniel pemberton - PERSON
# beauti - CARDINAL
# deservedli - PERSON
#
# Entities in text 621:
# first - ORDINAL
# one - CARDINAL
# everi singl - PERSON
# oneshameik - NORP
# incre movi - ORG
# miguel ohara - PERSON
# everi singl - PERSON
# cliffhang - ORG
# jawdrop - ORG
# spiderver one - CARDINAL
# one - CARDINAL
#
# Entities in text 622:
# jaw drop - PERSON
# gorgeou ton - PERSON
# cameo differ spiderman cartoon video game movi - PERSON
# one - CARDINAL
# next year - DATE
# everi spiderman - PERSON
# chase mile - ORG
# new york - ORG
# everyth movi - ORG
# stan lee - PERSON
#
# Entities in text 623:
# first - ORDINAL
# everi depart - PERSON
# first movi movi funni - ORG
# rewatch howev - PERSON
# next year - DATE
# one - CARDINAL
#
# Entities in text 624:
# spiderversevisu stunningli - ORG
# funni film - ORG
# two - CARDINAL
# heighten - GPE
# narr - PERSON
#
# Entities in text 625:
# mile battl - PERSON
# expans - NORP
# first - ORDINAL
# one - CARDINAL
# second - ORDINAL
# one - CARDINAL
#
# Entities in text 626:
# year next one - DATE
# funni content - ORG
#
# Entities in text 627:
# one - CARDINAL
# thrill - GPE
# first - ORDINAL
# qualiti - PERSON
# first - ORDINAL
# everi - ORG
# morov - PERSON
# morov - PERSON
#
# Entities in text 628:
# first - ORDINAL
# half - CARDINAL
# night - TIME
# realli heartfelt clear - PERSON
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 629:
# experi - NORP
#
# Entities in text 630:
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# half - CARDINAL
# narr - ORG
# first - ORDINAL
# first - ORDINAL
# two - CARDINAL
# three - CARDINAL
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 631:
# first - ORDINAL
# challeng explor - PERSON
# first movi depth - ORG
# bizarr - PERSON
#
# Entities in text 632:
# necessari experi captur beauti hard - ORG
# standalon movi definit - ORG
#
# Entities in text 633:
# first - ORDINAL
# one - CARDINAL
# peter parker - PERSON
# first - ORDINAL
# first - ORDINAL
# ten - CARDINAL
#
# Entities in text 634:
# one - CARDINAL
# jake johnson - PERSON
# issac - ORG
# one year - DATE
#
# Entities in text 635:
# one - CARDINAL
# second - ORDINAL
# eleven - CARDINAL
# everi depart - PERSON
# netflix inch tv - WORK_OF_ART
#
# Entities in text 636:
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 637:
# first - ORDINAL
# favorit movi year - DATE
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 638:
# separ dimen spiderman mile - ORG
# emerg brooklyn - PERSON
# first - ORDINAL
# plu - ORG
# one - CARDINAL
#
# Entities in text 639:
# honestli - PERSON
# first - ORDINAL
# compar tom holland - PERSON
# liter everi marvel - PERSON
#
# Entities in text 640:
# first - ORDINAL
# movi honestli - PERSON
# cliffhang aveng movi - ORG
# two - CARDINAL
# extrem disappointingplea - PERSON
#
# Entities in text 641:
# first - ORDINAL
# epic superhero movi - ORG
# southamerican spiderman - ORG
# half hour - TIME
# next mile - QUANTITY
#
# Entities in text 642:
# believ incomplet movi movi - ORG
# march - DATE
#
# Entities in text 643:
# first - ORDINAL
# first - ORDINAL
# anoth hour - TIME
#
# Entities in text 644:
# besid mile - ORG
# first - ORDINAL
# one - CARDINAL
# third - ORDINAL
#
# Entities in text 645:
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# funni - ORG
#
# Entities in text 646:
# movi fantast realli enjoy - ORG
# next onei - DATE
# one - CARDINAL
# hobi realli - PERSON
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 647:
# everi sen - PERSON
# first - ORDINAL
# second - ORDINAL
# today - DATE
#
# Entities in text 648:
# half hour - TIME
# one - CARDINAL
# month - DATE
# vfx - ORG
# next one - DATE
#
# Entities in text 649:
# mile - CARDINAL
# hardli relat - PERSON
# one - CARDINAL
# mumbai - GPE
# mayb - GPE
#
# Entities in text 650:
# one - CARDINAL
# believ spiderman ultim win - ORG
# resolut mile - QUANTITY
# funni earn lazi - ORG
# couldv bettera movi - ORG
#
# Entities in text 651:
# articul incre beauti film mani - ORG
# one - CARDINAL
# narr - PERSON
# everi scene - PERSON
# india - GPE
# movi soak everi pixel - PERSON
# orang mayb - PERSON
# orchestr piec - PERSON
# synth - CARDINAL
# first - ORDINAL
# thin constantli tri cake - PERSON
# india - GPE
# mile - PERSON
# first - ORDINAL
# jharrel jerom - PERSON
# earth mile - LOC
# wellunlik - ORG
# first - ORDINAL
# two - CARDINAL
# movi clinic - ORG
# ill fulli - PERSON
# peter parker - PERSON
# earth - LOC
# earth - LOC
# prowler - PERSON
# two - CARDINAL
# third - ORDINAL
# first - ORDINAL
# two - CARDINAL
# everi confid - PERSON
#
# Entities in text 652:
# everi singl - PERSON
# attentionth - ORDINAL
# first - ORDINAL
# seri - NORP
#
# Entities in text 653:
# one - CARDINAL
# everi scene - PERSON
# peter parker brilliantli - PERSON
# selfdiscoveri realli reson mein conclus - PERSON
# ten - CARDINAL
#
# Entities in text 654:
# first - ORDINAL
# chang - PERSON
# first - ORDINAL
#
# Entities in text 655:
# spiderver mile - QUANTITY
# kemp - ORG
# justin k thompson - PERSON
# egg - DATE
# jawdroppingli beauti kudo - PERSON
# spectacular mile - QUANTITY
# brian tyre - PERSON
# jeff - PERSON
# luna lauren - PERSON
# jake johnson - PERSON
# awesom peter - PERSON
# oscar isaac - PERSON
# miguel ohara jason - PERSON
# shea whigham - PERSON
# jessica draw - PERSON
# hobi brown - PERSON
# spidey - PERSON
#
# Entities in text 656:
# unlucki person - PERSON
# year - DATE
# relat - PERSON
#
# Entities in text 657:
# first - ORDINAL
# one - CARDINAL
# funni - ORG
# first - ORDINAL
# third - ORDINAL
#
# Entities in text 658:
# comicbook superhero movi - ORG
# spectacl visual - GPE
# paci - ORG
# moviego captiv - PERSON
# alon mani scene couldv - PERSON
# offerth - LOC
# genr realli film - PRODUCT
# issu realiti - PERSON
#
# Entities in text 659:
# one - CARDINAL
# seri - NORP
# two - CARDINAL
# one - CARDINAL
# jason schwartzman - PERSON
# first - ORDINAL
# second - ORDINAL
# half - CARDINAL
# two - CARDINAL
# solida - GPE
#
# Entities in text 660:
# one - CARDINAL
# mile - PERSON
# ben - PERSON
# peter parker - PERSON
# mode mile - PERSON
# one - CARDINAL
# mile - PERSON
# realiti - PERSON
#
# Entities in text 661:
# hour - TIME
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 662:
# villan young - ORG
# battl - PERSON
# one - CARDINAL
# second - ORDINAL
#
# Entities in text 663:
# first - ORDINAL
# film year - DATE
#
# Entities in text 664:
# christoph miller dave callaham - PERSON
# brilliantli - ORG
# worldbuild - PERSON
# servic metahumorth anim - PERSON
# gorgeou - NORP
# sens geographi - PERSON
# leonardo da vinci - PERSON
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 665:
# first - ORDINAL
# second - ORDINAL
#
# Entities in text 666:
# second - ORDINAL
# next year - DATE
# hour - TIME
# everi second - PERSON
# one - CARDINAL
# next year - DATE
# everi penni - PERSON
#
# Entities in text 667:
# year - DATE
# deserv - PERSON
# hour - TIME
# hour - TIME
# miguel - PERSON
# first - ORDINAL
# second - ORDINAL
#
# Entities in text 668:
# narr - PERSON
# curio audiencehowev - PERSON
# memor narr - PERSON
# experi movi fall - ORG
#
# Entities in text 669:
# one - CARDINAL
# first - ORDINAL
# qualiti - GPE
#
# Entities in text 670:
# last year - DATE
# everi singl - PERSON
# setanim movi big - ORG
# year - DATE
#
# Entities in text 671:
# two - CARDINAL
# first - ORDINAL
# first - ORDINAL
# second - ORDINAL
# mayb minut mani - PERSON
# everi joke - PERSON
#
# Entities in text 672:
# first - ORDINAL
# one - CARDINAL
# entireti movi - ORG
# next year - DATE
#
# Entities in text 673:
# one - CARDINAL
# egg - DATE
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
# egg - DATE
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 674:
# first - ORDINAL
# everi - ORG
#
# Entities in text 675:
# today - DATE
# first - ORDINAL
# mostli inspir - PERSON
# raimi - ORG
# andrew spidey minut detail - PERSON
# first - ORDINAL
# three - CARDINAL
#
# Entities in text 676:
# miguel hara - PERSON
#
# Entities in text 677:
# everi spiderman fan - PERSON
# everi singl - PERSON
# one - CARDINAL
# one - CARDINAL
# everi frame - PERSON
# vibrantli - ORG
# beauti transcend miracul - PERSON
# confront chang - PERSON
# chao - PERSON
# battl believ - PERSON
#
# Entities in text 678:
# one - CARDINAL
# funni - ORG
# funni - ORG
# one - CARDINAL
# myle - PERSON
# one - CARDINAL
# netflix - GPE
#
# Entities in text 679:
# experi doubtwhen movi end - ORG
# two hour - TIME
# ten - CARDINAL
#
# Entities in text 680:
# one - CARDINAL
# innov - PERSON
# first - ORDINAL
# slightli - GPE
# one - CARDINAL
# genr howev - PRODUCT
# first - ORDINAL
# one - CARDINAL
# narr - PERSON
# societi - PERSON
# societi spider - PERSON
# miguel enter mile - LAW
# confus - ORG
# societi - PERSON
# societi mile - PERSON
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# societi headquart - PERSON
# societi fund - PERSON
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# indian - NORP
# two - CARDINAL
# stereotyp superhero - ORG
# conveni creativ - PERSON
#
# Entities in text 681:
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# two half hour - TIME
# first - ORDINAL
# three - CARDINAL
#
# Entities in text 682:
# first - ORDINAL
# first - ORDINAL
# everi singl - PERSON
# overwhelmingli gorgeou - LOC
# perfectli - ORG
# howev snippet - PERSON
# year one - DATE
# matur jaw - PERSON
#
# Entities in text 683:
# third - ORDINAL
# averag movi - ORG
# third - ORDINAL
#
# Entities in text 684:
# india - GPE
# absolut beauti - PRODUCT
# one - CARDINAL
#
# Entities in text 685:
# year - DATE
#
# Entities in text 686:
# compani movi - ORG
# first - ORDINAL
#
# Entities in text 687:
# beauti - CARDINAL
# first - ORDINAL
# mile miguel - PERSON
# romanc mile - PERSON
#
# Entities in text 688:
# one - CARDINAL
# tobey - GPE
# maguir - GPE
#
# Entities in text 689:
# first - ORDINAL
# one - CARDINAL
# chao - PERSON
# india - GPE
# secondari - NORP
# india - GPE
# first - ORDINAL
# mile mile - QUANTITY
# dedic - PERSON
# peter parker - PERSON
# gwen mile - ORG
# activ - PERSON
# india - GPE
# mile secretli - PERSON
# mile - TIME
# parker betrayel - ORG
# mile - CARDINAL
# two - CARDINAL
# spidersocieti confront - ORG
# mile - PERSON
# societi send - PERSON
# mayb movi - ORG
# mile - PERSON
# reveng - PERSON
# yeah aveng - PERSON
#
# Entities in text 690:
# first hour - TIME
# first - ORDINAL
# second - ORDINAL
# tropey mile - QUANTITY
# first - ORDINAL
# one goe first hour second hour - TIME
#
# Entities in text 691:
# first - ORDINAL
# fox soni movi - ORG
# movi someon know - PERSON
# one - CARDINAL
# one - CARDINAL
# cameo forc - PERSON
# someth - ORDINAL
# one - CARDINAL
# funni - ORG
# year one - DATE
# nap chang - PERSON
# watchingtldr movi place - ORG
#
# Entities in text 692:
# narr - PERSON
# two - CARDINAL
# prowler mile - PERSON
# anoth mile - QUANTITY
# issu - PERSON
# one - CARDINAL
#
# Entities in text 693:
# second hour - TIME
# year pt manth - DATE
# muddi cool - FAC
#
# Entities in text 694:
# anim chang - PERSON
# mayb - GPE
#
# Entities in text 695:
# first - ORDINAL
# one - CARDINAL
# two - CARDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 696:
# one - CARDINAL
# thrill - GPE
# one - CARDINAL
# big prais movi - ORG
# year - DATE
# realli believ - PERSON
# everi moment - PERSON
#
# Entities in text 697:
# funni momentsemot mani - ORG
# first - ORDINAL
# one - CARDINAL
# experi - NORP
# anoth year - DATE
#
# Entities in text 698:
# first - ORDINAL
# first ine slightli make - ORG
# funni charact defintley - ORG
# associ - PERSON
# freeli - NORP
# mile teleport - PERSON
# indian - NORP
# british - NORP
# associ - PERSON
# indian - NORP
# british - NORP
# one - CARDINAL
# blatanlti oblivi - PERSON
# necessari - PERSON
# india - GPE
# weak middl - PERSON
# sampll nyc - FAC
# associ involv eschoth - PERSON
#
# Entities in text 699:
# one - CARDINAL
# two - CARDINAL
# one - CARDINAL
#
# Entities in text 700:
# first - ORDINAL
# supris - ORG
# first - ORDINAL
# one - CARDINAL
# last year half - DATE
#
# Entities in text 701:
# fx subsum storylin movi - ORG
# badli mumbl - ORG
# confus - ORG
#
# Entities in text 702:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
# issu movi end huge cliffhang - ORG
# everyon - CARDINAL
#
# Entities in text 703:
# moviego - GPE
# howev movi truli - ORG
# chang - PERSON
#
# Entities in text 704:
# year - DATE
# first - ORDINAL
# one - CARDINAL
# next year - DATE
# summari movi - ORG
#
# Entities in text 705:
# experi - NORP
# awesom piec artth - PERSON
# metro - FAC
# year - DATE
#
# Entities in text 706:
#
# Entities in text 707:
# shameik - LAW
# foe narr - PERSON
# peter - PERSON
# hilari - ORG
# johnson - PERSON
# camaraderi - NORP
# variou genr - PERSON
# reinforc idea - PERSON
# one - CARDINAL
#
# Entities in text 708:
# shameik - PRODUCT
# narr juggl - PERSON
# multipl plotlin - PERSON
# one - CARDINAL
#
# Entities in text 709:
#
# Entities in text 710:
# battl - PERSON
# bizarr - PERSON
# societi - PERSON
# chang - PERSON
# everyth - ORG
#
# Entities in text 711:
#
# Entities in text 712:
# first - ORDINAL
# next day - DATE
# cheesi onelin - PERSON
#
# Entities in text 713:
# awesom follow - PERSON
# mile gwen - PERSON
# realli click - PERSON
# first - ORDINAL
#
# Entities in text 714:
# ps - ORG
# miguel - PERSON
# one - CARDINAL
# metro - FAC
#
# Entities in text 715:
# indian - NORP
# superhero movi - ORG
# adventur - GPE
# miguel ohara - PERSON
# chao mile - PERSON
# surpris - NORP
#
# Entities in text 716:
# five year ago - DATE
# featur chang anim movi forev - ORG
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 717:
# one - CARDINAL
#
# Entities in text 718:
# howev storylin - PERSON
# first - ORDINAL
# mayb - GPE
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 719:
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 720:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# believ - GPE
# third - ORDINAL
# next year - DATE
#
# Entities in text 721:
# first - ORDINAL
# first - ORDINAL
# three year ago - DATE
# one - CARDINAL
# one - CARDINAL
# first - ORDINAL
# reek - GPE
# narr - PERSON
# two half hour - TIME
# closur - ORG
# cliffhang midturningpoint movi - ORG
# first - ORDINAL
# one - CARDINAL
# four year - DATE
# movi - ORG
# one - CARDINAL
# qualiti - ORG
#
# Entities in text 722:
# invit - ORG
# societi help - PERSON
# jessica draw issa rae defeat - PERSON
# jorma tacccon - PERSON
# societi - PERSON
# fix anomali month later - DATE
# shameik - PERSON
# jason schwartzman - PERSON
# second - ORDINAL
# voic daniel kaluuya - ORG
# india - GPE
# peter b parker - PERSON
# jake - CARDINAL
# second - ORDINAL
#
# Entities in text 723:
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 724:
# everi comic book - PERSON
# everi movi fan - PERSON
# everi - PERSON
# outwith mani refer easteregg - PERSON
# one - CARDINAL
#
# Entities in text 725:
# second - ORDINAL
# half - CARDINAL
# spectacl everyon - PERSON
#
# Entities in text 726:
# first - ORDINAL
# one - CARDINAL
# everi - PRODUCT
#
# Entities in text 727:
# one - CARDINAL
#
# Entities in text 728:
# issu - ORG
# innov - PERSON
# narr - PERSON
# film dedic fan newcom alik - PERSON
#
# Entities in text 729:
# verseth movi star - ORG
# jason schwartzmann - PERSON
# reveng mile - PERSON
# new york - GPE
#
# Entities in text 730:
# everi corner - PERSON
# storylin - GPE
# qualiti storylin - PERSON
#
# Entities in text 731:
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 732:
# bro movi - ORG
# plu - ORG
# first - ORDINAL
# leonardo da - PERSON
# one - CARDINAL
# complaint movi mile - ORG
# sidelin - PRODUCT
# peter - PERSON
# plotlin - PERSON
# first - ORDINAL
# one - CARDINAL
# mile tri - PERSON
# cliffhang actual wait long - ORG
# mysteri know mile - LAW
# jason schwartzman - PERSON
# one - CARDINAL
#
# Entities in text 733:
# year sinc mile - DATE
# new york - GPE
# lot chang mile tall explos - PERSON
# two - CARDINAL
# two - CARDINAL
#
# Entities in text 734:
# one - CARDINAL
# johnson - PERSON
# issac - ORG
# one year - DATE
#
# Entities in text 735:
# first - ORDINAL
# second - ORDINAL
# one two - CARDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 736:
# netflix - GPE
# histeria - GPE
# beauti - CARDINAL
# stan lee rip - PERSON
# posthum - PERSON
# one - CARDINAL
# compar editionsth bad guy - PERSON
#
# Entities in text 737:
# june - DATE
# gorgeou - NORP
# one - CARDINAL
# sam ramey spiderman - PERSON
#
# Entities in text 738:
# realli enjoy - PERSON
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# qualiti movi - ORG
# first - ORDINAL
# correctli - GPE
# everi scene - PERSON
# fulli - GPE
# phasetowhit canva - PERSON
# half - CARDINAL
# rick sanchez flavour - PERSON
# rick spider - PERSON
# fulli - GPE
# everi spiderman - PERSON
# slightli forc stitch - FAC
# first - ORDINAL
# second - ORDINAL
# third - ORDINAL
# slightli hint - PERSON
# everi spidey someon - PERSON
# uncl ben brief - PERSON
#
# Entities in text 739:
# everi part - PERSON
#
# Entities in text 740:
# first - ORDINAL
# one - CARDINAL
# heartson - PERSON
# first - ORDINAL
# surpris - NORP
# first - ORDINAL
# beauti - CARDINAL
# everi part - PERSON
# everi singl - PERSON
# second - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# realli beauti charact - PERSON
# two - CARDINAL
# first - ORDINAL
# one - CARDINAL
# second - ORDINAL
# one - CARDINAL
#
# Entities in text 741:
# narr - ORG
# amus breathtak visual spectacl everi frame - PERSON
# innov - PERSON
# narr - PERSON
# undeni - NORP
# narr - PERSON
#
# Entities in text 742:
# third - ORDINAL
#
# Entities in text 743:
# visual artistri heartfelt storytel - PERSON
# two - CARDINAL
# first - ORDINAL
#
# Entities in text 744:
# year - DATE
# dr strang - PERSON
#
# Entities in text 745:
# one - CARDINAL
# motionvari - PERSON
# miguel - PERSON
# trailer day - DATE
# mile - QUANTITY
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# everi singl - PERSON
# first - ORDINAL
# beauti piec artth - PERSON
# qualiti - GPE
# mike - PERSON
# one mile - QUANTITY
# cri - NORP
# first - ORDINAL
# one - CARDINAL
# seri - NORP
# everi movi - PERSON
# third - ORDINAL
# movi movi - ORG
#
# Entities in text 746:
# liveact movi movi - ORG
# third - ORDINAL
# second - ORDINAL
# one - CARDINAL
# third - ORDINAL
#
# Entities in text 747:
# nine - CARDINAL
# watch movi - ORG
# nine - CARDINAL
#
# Entities in text 748:
# first - ORDINAL
#
# Entities in text 749:
# first - ORDINAL
# half - CARDINAL
# second - ORDINAL
# half - CARDINAL
# repetit movi - ORG
# everi person - PERSON
#
# Entities in text 750:
# second - ORDINAL
# five year - DATE
# first - ORDINAL
# issu - PERSON
# second - ORDINAL
# chri miller - PERSON
# everyon creativ - PERSON
#
# Entities in text 751:
# triolog know - PERSON
# showcas - CARDINAL
# last year - DATE
# showcas - DATE
# ps game show exactli - PERSON
# ps marvel - ORG
#
# Entities in text 752:
# one - CARDINAL
# one - CARDINAL
# recent year - DATE
# shameik - PRODUCT
# jason schwartzman seemingli - PERSON
# week - DATE
# mile gwen - PERSON
# first - ORDINAL
# everi singl - PERSON
# miguel ohara - PERSON
# recent year - DATE
# two half hour - TIME
# two half hour - TIME
#
# Entities in text 753:
# honestli littl - PERSON
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# third - ORDINAL
# onei - NORP
#
# Entities in text 754:
# first - ORDINAL
# miguel ohara - PERSON
# secondari - NORP
# movi mile - PERSON
# tri destroy - PERSON
# societi tri - PERSON
# miguel ohara costum - ORG
#
# Entities in text 755:
# everi - PERSON
#
# Entities in text 756:
# last weekend - DATE
# june - DATE
# gorgeou - NORP
# first - ORDINAL
# mostli - GPE
# first - ORDINAL
# second - ORDINAL
# one - CARDINAL
# nich polit - PERSON
# oscar isaac - WORK_OF_ART
# seri - NORP
# half - CARDINAL
# india - GPE
# one - CARDINAL
# india - GPE
# one - CARDINAL
# seri - NORP
# wellbalanc movi - ORG
# first - ORDINAL
# third - ORDINAL
# second - ORDINAL
# ...
# one night - TIME
# miami - GPE
# first - ORDINAL
# everi singl - PERSON
# one - CARDINAL
#
# Entities in text 881:
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 882:
# yesterday - DATE
# one - CARDINAL
# miguel ohara - PERSON
# india - GPE
# miguel - PERSON
# mile honestli one - PERSON
# exactli - GPE
#
# Entities in text 883:
# five year - DATE
# next yearwheth - DATE
# narr - PERSON
# wellplac - ORG
# daniel kaluuya - PERSON
# jason schartzmanlik mention - PERSON
# tonn cameo - PERSON
# first - ORDINAL
# second - ORDINAL
#
# Entities in text 884:
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 885:
# storytellingon - NORP
# dri moment - PRODUCT
#
# Entities in text 886:
# first - ORDINAL
# half - CARDINAL
# hour - TIME
#
# Entities in text 887:
# ten - CARDINAL
# relat - PERSON
# motiv anim - PERSON
# first - ORDINAL
# miguel ohara - PERSON
# miguel ohara - PERSON
#
# Entities in text 888:
# everi moment - PERSON
# mile gwen - PERSON
# one - CARDINAL
# one - CARDINAL
# year howev end end - DATE
#
# Entities in text 889:
# everi - PERSON
# superbnowaday - DATE
# third - ORDINAL
#
# Entities in text 890:
# meticul - CARDINAL
# societi - PERSON
# hilari - NORP
#
# Entities in text 891:
# first - ORDINAL
# issu - GPE
# intro spiderversebut movi - ORG
#
# Entities in text 892:
# secondari - NORP
# mile extrem - PERSON
#
# Entities in text 893:
# goddamn movi incre - ORG
# one - CARDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 894:
# realli experi - PERSON
# experi - NORP
# indian - NORP
# one - CARDINAL
# avail netflix - PERSON
# first - ORDINAL
#
# Entities in text 895:
# rick morti - PERSON
# rick morti - PERSON
# mayb movi forc - ORG
# one - CARDINAL
#
# Entities in text 896:
# first - ORDINAL
# one - CARDINAL
# everyth movi - ORG
# perfectli - ORG
# combin beauti art make - PERSON
# one - CARDINAL
#
# Entities in text 897:
# first - ORDINAL
# one - CARDINAL
# first - ORDINAL
# pictur year - DATE
# first - ORDINAL
# everi scene - WORK_OF_ART
# everyth movi far - ORG
# experi - NORP
# pictur year - DATE
#
# Entities in text 898:
# first - ORDINAL
# jessica draw - PERSON
# india - GPE
#
# Entities in text 899:
# intro - PERSON
#
# Entities in text 900:
# everi - ORG
#
# Entities in text 901:
# first - ORDINAL
# aaron davi prowler - PERSON
# ps - PERSON
# andrew spiderman - PERSON
# stacey - PERSON
# ben spectacular - PERSON
# uncl ben scarlet - PERSON
#
# Entities in text 902:
#
# Entities in text 903:
# first - ORDINAL
# second - ORDINAL
# half - CARDINAL
#
# Entities in text 904:
# andrew garfield - PERSON
# tobi maguir - PERSON
#
# Entities in text 905:
# year - DATE
# one - CARDINAL
# let year - DATE
# mile gwen - PERSON
# peter much movi - PERSON
# everi singl - PERSON
# first - ORDINAL
#
# Entities in text 906:
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 907:
# someth hour - TIME
# diverg tradit superhero movi - ORG
#
# Entities in text 908:
# first - ORDINAL
# hilari - NORP
# second - ORDINAL
# funni - ORG
#
# Entities in text 909:
# month - DATE
# earth - LOC
# miguel ohara - PERSON
# everi - PERSON
# one - CARDINAL
# first - ORDINAL
# fulli - GPE
# rise challeng - PERSON
# miguel ohara - PERSON
# someth - ORDINAL
# one - CARDINAL
# mile - QUANTITY
# first - ORDINAL
# onin number instanc - ORG
# quot - PERSON
# sourc materi person - PERSON
# phil lord chri miller - PERSON
# david callaham - PERSON
# kemp - ORG
# justin k thompson - PERSON
# first - ORDINAL
# one - CARDINAL
# narr - PERSON
# first - ORDINAL
# one year - DATE
# david callaham - PERSON
# wildli creativ - PERSON
# isaac jason schwartzman issa rae - PERSON
#
# Entities in text 910:
# entertain movi bit complic realli overr - ORG
# everyon - CARDINAL
# issu mayb - PERSON
# headach - PERSON
# undeni - NORP
# first - ORDINAL
#
# Entities in text 911:
# first - ORDINAL
# one - CARDINAL
# style chang - PERSON
# importantli chang - PERSON
# knowit spectacl howev - PERSON
# everi twist - PERSON
# first - ORDINAL
# one - CARDINAL
# plu memor - PERSON
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
# slightli - GPE
# one two - CARDINAL
# second - ORDINAL
# one - CARDINAL
# third - ORDINAL
# first - ORDINAL
# two - CARDINAL
# first - ORDINAL
# two - CARDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 912:
# one - CARDINAL
# second - ORDINAL
# everi frame - PERSON
# everi - PRODUCT
# three - CARDINAL
# everi weekend - PERSON
#
# Entities in text 913:
# first - ORDINAL
# heartfelt sincer - PERSON
# insan wacki - PERSON
# togeth - CARDINAL
# miller - ORG
# one - CARDINAL
# one - CARDINAL
# one exceptionmoreov - QUANTITY
#
# Entities in text 914:
# someth - ORDINAL
# first - ORDINAL
# spectacl - ORG
# narr heartwarm - PERSON
# believ - GPE
# narr reson - PERSON
# journey tug heartstr - PERSON
# infus - NORP
# extraordinari adventur - PERSON
# treasur leav - PERSON
#
# Entities in text 915:
# finish movi day ago - DATE
# everi frame - PERSON
# next year - DATE
#
# Entities in text 916:
# one - CARDINAL
# funni spidervers - ORG
# chang mile - PERSON
# hilari - ORG
# reveng - PERSON
# mile - PERSON
# mani - PERSON
# stop mile - QUANTITY
# everyth surpris - PERSON
# one - CARDINAL
# first - ORDINAL
# promot movi - ORG
# india - GPE
# peter - PERSON
# one - CARDINAL
# ps game reason - ORG
# societi quickli - PERSON
#
# Entities in text 917:
# half - CARDINAL
# hilari - NORP
# half - CARDINAL
# microscop chang - PERSON
# funni - ORG
#
# Entities in text 918:
# experi - NORP
# liter enjoy - PERSON
# second - ORDINAL
# first - ORDINAL
# one - CARDINAL
# assur - GPE
# second - ORDINAL
# headlin - GPE
# first - ORDINAL
#
# Entities in text 919:
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# five year - DATE
# issu - ORG
# relat - PERSON
# india - GPE
# jessica drewspiderwoman - PERSON
# ben reillyscarlet - PERSON
# cool funni movi lastli - ORG
# doingth - PERSON
# week - DATE
# funni - ORG
# first - ORDINAL
# everi singl - PERSON
# cameo plu - PERSON
# peter - PERSON
# johnson movi - PERSON
# peter young - PERSON
# everi dimen beauti - PERSON
# india - GPE
# mumbattan - GPE
# nueva york - GPE
# plu - ORG
# liveact stylesbecaus movi - ORG
# one - CARDINAL
# second - ORDINAL
# first - ORDINAL
# first - ORDINAL
# two hour - TIME
#
# Entities in text 920:
# first - ORDINAL
# mile mani - PERSON
# first - ORDINAL
# titl past year - DATE
#
# Entities in text 921:
# first - ORDINAL
# first - ORDINAL
# beauti - CARDINAL
# imageri - NORP
# hundr referenceseast egg - ORG
# relat - PERSON
# nitpick someth - PERSON
# first - ORDINAL
# first - ORDINAL
# one - CARDINAL
# two come next year - DATE
# chang - PERSON
# spiderver one - CARDINAL
# expans - NORP
# expertli spin - PERSON
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 922:
# one - CARDINAL
#
# Entities in text 923:
# raini melancholi - ORG
# new york - GPE
# imageri - NORP
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 924:
# first - ORDINAL
# two hour - TIME
#
# Entities in text 925:
# one - CARDINAL
# first - ORDINAL
# seri - NORP
# ten - CARDINAL
# wor convolut - PERSON
# two - CARDINAL
# mostli nostalg - FAC
# plu - ORG
#
# Entities in text 926:
# first - ORDINAL
# one - CARDINAL
# mike tri figur - PERSON
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 927:
# ish month - DATE
# everi scene - PERSON
# everi - NORP
# two - CARDINAL
#
# Entities in text 928:
# prowler cliffhang - PERSON
# two - CARDINAL
# kid dan ect - PERSON
#
# Entities in text 929:
# one - CARDINAL
# one - CARDINAL
# hilari - NORP
# next onei - DATE
# first - ORDINAL
# everyon - CARDINAL
# everyth movi perfect - ORG
# beauti mani rich color - PERSON
# two - CARDINAL
# second - ORDINAL
#
# Entities in text 930:
# activ - PERSON
# superhero - ORG
# realli enjoy movi - PERSON
#
# Entities in text 931:
# seri - NORP
# year - DATE
# seri - ORG
# unlimit sam raimi trilog - PERSON
# seri - NORP
# year - DATE
#
# Entities in text 932:
# second - ORDINAL
# fed - ORG
# mess soo rate movi - ORG
#
# Entities in text 933:
#
# Entities in text 934:
# happi movi one - ORG
# beauti surpris - PERSON
# guy truli - PERSON
#
# Entities in text 935:
# prowler mile - PERSON
# jaw watch - PERSON
# indian - NORP
# detail movi - ORG
# everi second - PERSON
#
# Entities in text 936:
# year ago - DATE
# honestlyyesterday - DATE
# one - CARDINAL
# experi truli - ORG
# everyth honestli - PERSON
# two - CARDINAL
#
# Entities in text 937:
# chang - PERSON
# last year - DATE
#
# Entities in text 938:
# everi singl - PERSON
# second - ORDINAL
# second - ORDINAL
# experi - NORP
# metro - FAC
#
# Entities in text 939:
# experi - NORP
# catchi memor realli - PERSON
#
# Entities in text 940:
# tom holland - PERSON
# one - CARDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 941:
# first - ORDINAL
# first - ORDINAL
# metro - FAC
# one - CARDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 942:
# one - CARDINAL
# five - CARDINAL
# appli latin - PERSON
# one - CARDINAL
# surpris movi - ORG
# spectacl - ORG
# one - CARDINAL
#
# Entities in text 943:
#
# Entities in text 944:
# stacey spiderwoman - PERSON
# first - ORDINAL
# spectacl - ORG
# first hour - TIME
# chang - PERSON
# first - ORDINAL
# issu - ORG
# kick jam - PERSON
# first hour - TIME
#
# Entities in text 945:
# everyth movi - ORG
# first - ORDINAL
# third - ORDINAL
# everi actor - PERSON
# mile - PERSON
# two - CARDINAL
# fourth - ORDINAL
# two - CARDINAL
# everi spiderman - PERSON
#
# Entities in text 946:
# honestli movi - ORG
# everi singl - PERSON
# second - ORDINAL
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
# everi detail - PERSON
#
# Entities in text 947:
# first - ORDINAL
# second - ORDINAL
# third - ORDINAL
# half - CARDINAL
# first - ORDINAL
# half - CARDINAL
# dramat mannerpun - PERSON
# first - ORDINAL
# one - CARDINAL
# funni - ORG
#
# Entities in text 948:
#
# Entities in text 949:
# chilli funni ambienc - ORG
# year mile - DATE
# miguel - PERSON
# one - CARDINAL
#
# Entities in text 950:
# year - DATE
# buff - PERSON
#
# Entities in text 951:
# knight empir - PERSON
# america - GPE
# winter - DATE
# first - ORDINAL
#
# Entities in text 952:
# two - CARDINAL
#
# Entities in text 953:
# genuin surpris - PERSON
# first - ORDINAL
# everi aspectth - PERSON
# first - ORDINAL
# chang univer - PERSON
# superhero movi mile - ORG
# peter parker - PERSON
# miguel ohara uniqu - PERSON
# narr - PERSON
# next year - DATE
# seri - NORP
# qualiti - PERSON
# qualiti - PERSON
# one - CARDINAL
# greatli - PERSON
#
# Entities in text 954:
#
# Entities in text 955:
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 956:
# oppenheim - NORP
# day - DATE
# one - CARDINAL
# today - DATE
# kick butt - PERSON
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 957:
# issu - PERSON
# first - ORDINAL
# one - CARDINAL
# issu - ORG
# immin - GPE
# half - CARDINAL
# indian - NORP
#
# Entities in text 958:
# first - ORDINAL
# reson realiti - PERSON
# thousand - CARDINAL
# one - CARDINAL
# one - CARDINAL
# first - ORDINAL
# specif loki - ORG
# seri - NORP
# year - DATE
#
# Entities in text 959:
# everi detail beauti make - PERSON
# mile - PERSON
# third - ORDINAL
#
# Entities in text 960:
# anoth year - DATE
# gpt - ORG
# swing street - ORG
# new york - GPE
# relat person inspir - PERSON
#
# Entities in text 961:
# hilari - NORP
# creativ anim - PERSON
#
# Entities in text 962:
#
# Entities in text 963:
# myle - ORG
# first - ORDINAL
#
# Entities in text 964:
# everi - PERSON
# first - ORDINAL
# relat believ - PERSON
# third - ORDINAL
#
# Entities in text 965:
# miguel ohara - PERSON
# somenth - ORDINAL
#
# Entities in text 966:
# first - ORDINAL
# first film villainth kingpinwhat - DATE
# thousand - CARDINAL
# hundr - ORG
#
# Entities in text 967:
# one - CARDINAL
# two - CARDINAL
# first - ORDINAL
# one - CARDINAL
# brian tyre - PERSON
# johnson - PERSON
# realli embodi - PERSON
# indian - NORP
# experi - NORP
# british - NORP
# funni time - ORG
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# first - ORDINAL
# one two - CARDINAL
# cliffhang pace bit - ORG
# one two - CARDINAL
# one two - CARDINAL
# messag movi movi - ORG
# leav middl - PERSON
# first - ORDINAL
# indian - NORP
# one - CARDINAL
#
# Entities in text 968:
# mile courseth - PERSON
#
# Entities in text 969:
# rewatch - NORP
# qualiti groundbreak everi - PERSON
# second - ORDINAL
# half - CARDINAL
# funni - ORG
#
# Entities in text 970:
# first - ORDINAL
# gorgeou - NORP
# first - ORDINAL
# hillari filmeveryth film truli - ORG
#
# Entities in text 971:
# indian - NORP
# day - DATE
#
# Entities in text 972:
# one - CARDINAL
# year - DATE
# tissu - ORG
# two - CARDINAL
#
# Entities in text 973:
# qualiti one first - PERSON
# plotlin stun - PERSON
# spiderversea starstud voic - PERSON
# expertli explor - PERSON
# spiderverseth bigbad - GPE
# surpris - NORP
# miguel ohara - PERSON
# gravita miguel - PERSON
# easi - ORG
# miguel vampireninja trait - PERSON
# mile miguel ohara - PERSON
# jorma taccon - ORG
# voic jason - PERSON
# dr jonathan ohnn aka - PERSON
# angl mile - ORG
# two - CARDINAL
# india - GPE
# mumbai - GPE
# mumbattan everyth - ORG
# pavitr prabhakar indian - PERSON
# new york - GPE
# nueva york earth - GPE
# societi - PERSON
# dedic pace detail - PERSON
# multispidey - ORG
# third mile - QUANTITY
#
# Entities in text 974:
# first - ORDINAL
# daniel pemberton - PERSON
# metro - ORG
# everyon - CARDINAL
# next year - DATE
# genr superhero movi - ORG
#
# Entities in text 975:
# first - ORDINAL
# second - ORDINAL
# first - ORDINAL
# one - CARDINAL
#
# Entities in text 976:
# first - ORDINAL
# becam appar - PERSON
# one - CARDINAL
#
# Entities in text 977:
# first - ORDINAL
# one - CARDINAL
# one - CARDINAL
#
# Entities in text 978:
#
# Entities in text 979:
# first - ORDINAL
# messi storylin - PERSON
# strang place - PERSON
# everi person - PERSON
# first - ORDINAL
# everi spiderman - PERSON
# everi - PERSON
#
# Entities in text 980:
# first - ORDINAL
# second - ORDINAL
# funni - ORG
# one - CARDINAL
#
# Entities in text 981:
# howev - GPE
# qualiti - GPE
# qualiti - GPE
# qualiti - PERSON
# pixar - PERSON
#
# Entities in text 982:
# breathtak tapestri - PERSON
# innov - PERSON
# first - ORDINAL
# spectacl - ORG
# everi frame meticul craft - PERSON
# journey spiderman - PERSON
# moment laughoutloud - PERSON
# shameik - NORP
# relat inspir - PERSON
# miguel ohara - PERSON
# theme narr leav - PERSON
# boundari - ORG
# visionari filmmak - ORG
# potenti storytel - PERSON
# visionari - NORP
#
# Entities in text 983:
# spiderversethi movi - ORG
# two - CARDINAL
# one - CARDINAL
# two - CARDINAL
# one - CARDINAL
#
# Entities in text 984:
# first - ORDINAL
# correctli - GPE
# first - ORDINAL
# relat - PERSON
# issu - ORG
# second - ORDINAL
#
# Entities in text 985:
# first - ORDINAL
# howev massiv cliffhang - PERSON
# howev - GPE
#
# Entities in text 986:
# third - ORDINAL
# next year - DATE
#
# Entities in text 987:
# first - ORDINAL
# one - CARDINAL
# awesom capit blow - PERSON
# believ - GPE
#
# Entities in text 988:
# everi part - PERSON
# thrill - GPE
# plu - ORG
# indian - NORP
# prabhakar karan - PERSON
# challeng kid fulli - PERSON
# first - ORDINAL
#
# Entities in text 989:
# second - ORDINAL
# second - ORDINAL
# aaron - PERSON
# mile prowler - PERSON
#
# Entities in text 990:
# first - ORDINAL
# one - CARDINAL
# everi time - PERSON
# asapcan - NORP
# million - CARDINAL
#
# Entities in text 991:
# sjsjkdkabdjd honestli - PERSON
# theater chang - PERSON
#
# Entities in text 992:
# two half hour - TIME
# first - ORDINAL
# last one - DATE
#
# Entities in text 993:
# first - ORDINAL
# villan - GPE
#
# Entities in text 994:
# first - ORDINAL
# first - ORDINAL
#
# Entities in text 995:
# first - ORDINAL
# metro - FAC
#
# Entities in text 996:
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 997:
# one - CARDINAL
# creativ movi - ORG
# one - CARDINAL
# first - ORDINAL
#
# Entities in text 998:
# year - DATE
# believ mile - ORG
# first - ORDINAL
# last second - DATE
# extrem - PERSON
# almost hour - TIME
# shi hour - PERSON
# third - ORDINAL
# john - PERSON
# first - ORDINAL
# first - ORDINAL
# second - ORDINAL
# awesom titl - PERSON
# seri - NORP
# carefulwond detail - PERSON
# one - CARDINAL
# today - DATE
# onlin - GPE
# weekend - DATE
# one - CARDINAL
# tenth - ORDINAL
# one - CARDINAL
# hour - TIME
#
# Entities in text 999:
# briefli review - ORG
# year - DATE
# two - CARDINAL
# three - CARDINAL
# first - ORDINAL
# peter b parker - PERSON
# first - ORDINAL
# second - ORDINAL
# third - ORDINAL
# fourth - ORDINAL
# fifth - ORDINAL
# theater februari - PERSON
# year - DATE
# mostli - GPE
# sixth - ORDINAL
# half day - DATE
# phil lord - PERSON
# christoph miller - PERSON
#
# Entities in text 1000:
# last year - DATE
# everyth - PERSON
# summer - DATE
#
# Total entity counts:
# PERSON: 1823
# ORDINAL: 1095
# NORP: 284
# TIME: 143
# CARDINAL: 1063
# ORG: 724
# DATE: 315
# GPE: 232
# WORK_OF_ART: 10
# QUANTITY: 50
# PRODUCT: 57
# FAC: 25
# EVENT: 3
# LANGUAGE: 3
# MONEY: 2
# LOC: 12
# LAW: 11
#
# Sample of unique entities found (up to 20):
# handcuff - GPE
# subtitl movi sadli - ORG
# storytel massiv - ORG
# kung - GPE
# ago half - CARDINAL
# insan movi great movi realli bad movi movi - ORG
# spiderpersonth - CARDINAL
# lesson impart - PERSON
# insert everi singl - PERSON
# angri horrif - PERSON
# everi metric fathomit far - WORK_OF_ART
# monalisa whole movi remark - ORG
# whenev convers - ORG
# peter miguel - PERSON
# mostli inspir - PERSON
# cheesi onelin - PERSON
# luna lauren - PERSON
# magnific - TIME
# articul incre beauti film mani - ORG
# chao film - PERSON
#
# Full list of named entities saved to 'named_entities.csv'

# %% [markdown]
# #**Comment**
# Make sure to submit the cleaned data CSV in the comment section - 10 points

# %%
dataFrame.to_csv('final_cleaned_dataset.csv', index=False)
print("Final cleaned dataset with all steps saved to 'final_cleaned_dataset.csv'")
# Out:
# Final cleaned dataset with all steps saved to 'final_cleaned_dataset.csv'

# %%
import pandas as pd

# Loading the final cleaned CSV file
dataFrame = pd.read_csv('final_cleaned_dataset.csv')

# Keeping only the final cleaned 'Lemmatized' column since it is the last step performed and renaming it to 'Final Review'
final_dataFrame = dataFrame[['Lemmatized']].rename(columns={'Lemmatized': 'Final Review'})

# Saving the entire final dataset to a new CSV file called 'final_reviews_dataset.csv'
final_dataFrame.to_csv('final_reviews_dataset.csv', index=False)

# Print a final confirmation message
print("Cleaned and final reviews dataset has been saved to 'final_reviews_dataset.csv'")
# Out:
# Cleaned and final reviews dataset has been saved to 'final_reviews_dataset.csv'

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %%
# Write your response below

'''

The assignment was engaging, especially the text processing techniques that improved the quality of movie reviews. I found it challenging to handle certain tasks like removing noise and stemming words. I enjoyed using NLP techniques, particularly Named Entity Recognition, to identify different entities in the text. The time provided felt reasonable, allowing me to explore concepts without feeling rushed.
'''
# Out:
# '\n\nThe assignment was engaging, especially the text processing techniques that improved the quality of movie reviews. I found it challenging to handle certain tasks like removing noise and stemming words. I enjoyed using NLP techniques, particularly Named Entity Recognition, to identify different entities in the text. The time provided felt reasonable, allowing me to explore concepts without feeling rushed.\n'
